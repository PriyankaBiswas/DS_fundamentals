# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data.csv') #loading data
#print(df.head()) 
df.shape # 2722 rows and 15 columns 
#data published originally at the Guardian Apr 15, 2011
# Out:
# (2722, 15)

# %%
#Data preparation 
#deleting repeated and unwanted columns 

df = df.drop(['Name in the language','Name in French', 'Name in Spanish', 'ISO639-3 codes','Sources', 'Description of the location'], axis=1)
df.shape #2722,9
# Out:
# (2722, 9)

# %%
#renaming column names
df.rename(columns={'Number of speakers': 'Speakers',
                   'Country code': 'Country_code',
                   'Degree of endangerment': 'Endangerment',
                   'Name in English':'Language',
                  'Country codes alpha 3':'Country code'}, inplace=True)

# %%
df
# Out:
#         ID                                    Language  \
# 0     1022                               South Italian
# 1     1023                                    Sicilian
# 2      383                                   Low Saxon
# 3      335                                  Belarusian
# 4      382                                     Lombard
# 5      405                                      Romani
# 6     2211                            Yiddish (Israel)
# 7     1586                                       Gondi
# 8     1020                        Limburgian-Ripuarian
# 9     1943                 Quechua of Southern Bolivia
# 10    1565                                     Kumaoni
# 11     755                                      Aymara
# 12     349                            Emilian-Romagnol
# 13     399                                 Piedmontese
# 14    1021                                     Venetan
# 15    1985                                      Zazaki
# 16    1591                               Kurux (India)
# 17    2065                                     Tamajeq
# 18    1585                                        Tulu
# 19    1556                                      Kangdi
# 20     410                                       Scots
# 21    1026                                      Torlak
# 22    1476                                West Flemish
# 23     334                                     Bashkir
# 24    1067                                     Chechen
# 25     338                                     Chuvash
# 26    1227                                     Meithei
# 27    1114                                      Tamang
# 28    1013                            Quechua of Cuzco
# 29    1024                              Eastern Slovak
# ...    ...                                         ...
# 2692     3                                    Tasnusit
# 2693  1059                                         Tat
# 2694  1495                                        Tati
# 2695  2012                                      Tatuyo
# 2696   457                                        Tazy
# 2697  2458                                     Tempuan
# 2698  2188                                 Toba-Maskoy
# 2699   447                                      Tolcha
# 2700  2182                         Touggourt Tamazight
# 2701  2009                           Tucano (Colombia)
# 2702  2453              Tunisian Judeo-Arabic (Israel)
# 2703  2391                          Tuscarora (Canada)
# 2704  2013                           Tuyuca (Colombia)
# 2705  2192                               Udi (Georgia)
# 2706   280                                       Unami
# 2707  2392                       Upper Tanana (Canada)
# 2708  1336                                        Urum
# 2709  2475                                          Wa
# 2710  2014                 Wanano / Kotiria (Colombia)
# 2711  2393                    Western Abenaki (Canada)
# 2712   283  Western Abenaki (United States of America)
# 2713  2093                                       Wichi
# 2714  1971                                     Yaeyama
# 2715  1365                                  Yazva Komi
# 2716   428                            Yiddish (Europe)
# 2717  1972                                    Yonaguni
# 2718  2018                                      Yucuna
# 2719  2015                           Yurutí (Colombia)
# 2720  2716                                   Zangskari
# 2721  2177                                     Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# 7                                                 India
# 8                         Germany, Belgium, Netherlands
# 9                      Bolivia (Plurinational State of)
# 10                                         India, Nepal
# 11        Bolivia (Plurinational State of), Chile, Peru
# 12                                    Italy, San Marino
# 13                                                Italy
# 14                             Croatia, Italy, Slovenia
# 15                                               Turkey
# 16                                                India
# 17                                                Niger
# 18                                                India
# 19                                                India
# 20    United Kingdom of Great Britain and Northern I...
# 21    Albania, Bulgaria, The former Yugoslav Republi...
# 22                         Belgium, France, Netherlands
# 23                                   Russian Federation
# 24                                   Russian Federation
# 25                                   Russian Federation
# 26                                                India
# 27                                         India, Nepal
# 28                                                 Peru
# 29                                    Slovakia, Ukraine
# ...                                                 ...
# 2692                                            Algeria
# 2693                                         Azerbaijan
# 2694                         Iran (Islamic Republic of)
# 2695                                           Colombia
# 2696                                 Russian Federation
# 2697                                           Cambodia
# 2698                                           Paraguay
# 2699                                              India
# 2700                                            Algeria
# 2701                                           Colombia
# 2702                                             Israel
# 2703                                             Canada
# 2704                                           Colombia
# 2705                                            Georgia
# 2706                           United States of America
# 2707                                             Canada
# 2708               Georgia, Russian Federation, Ukraine
# 2709                                            Myanmar
# 2710                                           Colombia
# 2711                                             Canada
# 2712                           United States of America
# 2713        Argentina, Bolivia (Plurinational State of)
# 2714                                              Japan
# 2715                                 Russian Federation
# 2716  Germany, Austria, Belarus, Belgium, Denmark, E...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# 2720                                    India, Pakistan
# 2721                                               Oman
#
#                                            Country code  \
# 0                                                   ITA
# 1                                                   ITA
# 2                               DEU, DNK, NLD, POL, RUS
# 3                          BRB, LVA, LTU, POL, RUS, UKR
# 4                                              ITA, CHE
# 5     ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, F...
# 6                                                   ISR
# 7                                                   IND
# 8                                         DEU, BEL, NLD
# 9                                                   BOL
# 10                                             IND, NPL
# 11                                        BOL, CHL, PER
# 12                                             ITA, SMR
# 13                                                  ITA
# 14                                        HRV, ITA, SVN
# 15                                                  TUR
# 16                                                  IND
# 17                                                  NER
# 18                                                  IND
# 19                                                  IND
# 20                                                  GBR
# 21                              ALB, BGR, MKD, ROU, SRB
# 22                                        BEL, FRA, NLD
# 23                                                  RUS
# 24                                                  RUS
# 25                                                  RUS
# 26                                                  IND
# 27                                             IND, NPL
# 28                                                  PER
# 29                                             SVK, UKR
# ...                                                 ...
# 2692                                                DZA
# 2693                                                AZE
# 2694                                                IRN
# 2695                                                COL
# 2696                                                RUS
# 2697                                                KHM
# 2698                                                PRY
# 2699                                                IND
# 2700                                                DZA
# 2701                                                COL
# 2702                                                ISR
# 2703                                                CAN
# 2704                                                COL
# 2705                                                GEO
# 2706                                                USA
# 2707                                                CAN
# 2708                                      GEO, RUS, UKR
# 2709                                                MMR
# 2710                                                COL
# 2711                                                CAN
# 2712                                                USA
# 2713                                           ARG, BOL
# 2714                                                JPN
# 2715                                                RUS
# 2716  DEU, AUT, BRB, BEL, DNK, EST, FIN, FRA, HUN, I...
# 2717                                                JPN
# 2718                                                COL
# 2719                                                COL
# 2720                                           IND, PAK
# 2721                                                OMN
#
#                Endangerment  \
# 0                Vulnerable
# 1                Vulnerable
# 2                Vulnerable
# 3                Vulnerable
# 4     Definitely endangered
# 5     Definitely endangered
# 6     Definitely endangered
# 7                Vulnerable
# 8                Vulnerable
# 9                Vulnerable
# 10               Vulnerable
# 11               Vulnerable
# 12    Definitely endangered
# 13    Definitely endangered
# 14               Vulnerable
# 15               Vulnerable
# 16               Vulnerable
# 17               Vulnerable
# 18               Vulnerable
# 19    Definitely endangered
# 20               Vulnerable
# 21               Vulnerable
# 22               Vulnerable
# 23               Vulnerable
# 24               Vulnerable
# 25               Vulnerable
# 26               Vulnerable
# 27               Vulnerable
# 28               Vulnerable
# 29               Vulnerable
# ...                     ...
# 2692    Severely endangered
# 2693    Severely endangered
# 2694  Definitely endangered
# 2695  Definitely endangered
# 2696    Severely endangered
# 2697    Severely endangered
# 2698    Severely endangered
# 2699                Extinct
# 2700    Severely endangered
# 2701             Vulnerable
# 2702    Severely endangered
# 2703  Critically endangered
# 2704  Definitely endangered
# 2705    Severely endangered
# 2706                Extinct
# 2707  Critically endangered
# 2708  Definitely endangered
# 2709    Severely endangered
# 2710  Definitely endangered
# 2711  Critically endangered
# 2712                Extinct
# 2713             Vulnerable
# 2714    Severely endangered
# 2715    Severely endangered
# 2716  Definitely endangered
# 2717    Severely endangered
# 2718  Definitely endangered
# 2719  Definitely endangered
# 2720  Definitely endangered
# 2721  Critically endangered
#
#                                         Alternate names   Speakers  Latitude  \
# 0     Neapolitan; Neapolitan-Calabrese; неаполитанск...  7500000.0   40.9798
# 1                                                   NaN  5000000.0   37.4399
# 2     Low German, Niedersächsisch, Nedersaksisch, Ni...  4800000.0   53.4029
# 3                                                   NaN  4000000.0   53.9560
# 4                                                   NaN  3500000.0   45.7215
# 5                                    sinti, vlax,  calò  3500000.0   46.3165
# 6                                          Judeo-German  3000000.0   32.0833
# 7     Gondi; Gaudi; Gondiva; Gondwadi; Goondile; Gou...  2713790.0   19.5804
# 8                Colognian (dialect; in German: Kölsch)  2600000.0   50.7781
# 9                                                   NaN  2300000.0  -18.0675
# 10           Kumauni; Kamaoni; Kumau; Kumawani; Kumgoni  2003783.0   29.4778
# 11                   Aimara, Jaqi Aru, Southern Aymara.  2000000.0  -16.5835
# 12                                                  NaN  2000000.0   44.1270
# 13                                                  NaN  2000000.0   45.2013
# 14                                                  NaN  2000000.0   45.4601
# 15                               Zaza; Dimli; Kirmanjki  2000000.0   38.8824
# 16                                        Kurukh; Oraon  1751489.0   22.1467
# 17                                                  NaN  1750000.0   17.2352
# 18       Tuluva Bhasa; Tullu; Thulu; Tal; Tilu; Thalu\n  1722768.0   12.0178
# 19    Dogaryali; Dogri Pahari;  Tokkaru; Dogri-Kangr...  1700000.0   32.4356
# 20        Lallans; Northumbrian (local name in England)  1500000.0   56.2189
# 21             Shop; dialects: Goran, Janjev, Krashovan  1500000.0   42.9644
# 22                  Western Flemish; Zeelandic (Zeêuws)  1500000.0   51.0275
# 23                                             Bashkort  1379727.0   54.7309
# 24                                                  NaN  1331844.0   43.1971
# 25                                                  NaN  1325382.0   56.1394
# 26                                     Manipuri, Meitei  1250000.0   24.7667
# 27                     तामाङ; तामाङ्ग; Murmi (obsolete)  1196639.0   27.7365
# 28                                 Quechua Cuzco-Collao  1115000.0  -13.4537
# 29                                                  NaN  1000000.0   48.8068
# ...                                                 ...        ...       ...
# 2692  Tamazight, Berbere du Beni Snous, Ayt Snous, C...        NaN   34.6230
# 2693                                                NaN        NaN   41.3438
# 2694                      Tātī; Azari; Āẕarī; Takestani        NaN   38.2036
# 2695                                                NaN        NaN    0.4174
# 2696                                                Taz        NaN   43.9236
# 2697                                                NaN        NaN   13.7238
# 2698                                                NaN        NaN  -21.5578
# 2699                                                NaN        NaN   29.9333
# 2700  Righia, Chelha, Shelha\nGeneric term of Tamazight        NaN   33.0777
# 2701                                             Tukáno        NaN    0.6921
# 2702                        l'arabe des juifs tunisiens        NaN   32.0779
# 2703                                                NaN        NaN   43.0720
# 2704                                             Tuyúka        NaN    0.3515
# 2705                                                NaN        NaN   41.8905
# 2706                Delaware, Oklahoma Delaware, Lenape        NaN   39.1300
# 2707                                                NaN        NaN   62.3824
# 2708                                        Greek Tatar        NaN   47.0102
# 2709                                                NaN        NaN   21.8705
# 2710     Guanano, Kotiria is autodenomination in Brazil        NaN    1.0106
# 2711                                                NaN        NaN   46.0785
# 2712                                                NaN        NaN   43.0046
# 2713  Wichi, Weenhayek, Wichí Lhamtés Nocten , Wichí...        NaN  -22.0041
# 2714                                                NaN        NaN   24.3420
# 2715                                    Eastern Permyak        NaN   60.0348
# 2716                                       Judeo-German        NaN   53.3571
# 2717                                                NaN        NaN   24.4580
# 2718                                                NaN        NaN   -1.2633
# 2719                                                NaN        NaN    1.1370
# 2720                               Zangs-dkar, Z’angkar        NaN   34.0833
# 2721                                   Zidjali, Zadjali        NaN   23.4027
#
#       Longitude
# 0       15.2490
# 1       14.5019
# 2       10.3601
# 3       27.5756
# 4        9.3273
# 5       22.3681
# 6       34.8333
# 7       80.4418
# 8        6.0864
# 9      -65.7641
# 10      79.8486
# 11     -68.3020
# 12      12.0739
# 13       7.8662
# 14      12.1948
# 15      40.4846
# 16      85.2758
# 17       8.0859
# 18      75.7067
# 19      76.1242
# 20      -3.7683
# 21      22.1374
# 22       3.0541
# 23      55.9863
# 24      45.7031
# 25      47.2412
# 26      93.8946
# 27      85.6858
# 28     -72.0098
# 29      21.7968
# ...         ...
# 2692    -1.5614
# 2693    48.6254
# 2694    48.2519
# 2695   -70.4882
# 2696   134.7967
# 2697   107.2038
# 2698   -58.0064
# 2699    80.0326
# 2700     6.0671
# 2701   -69.8291
# 2702    34.8019
# 2703   -80.0150
# 2704   -70.2026
# 2705    45.9130
# 2706   -76.0253
# 2707  -140.8984
# 2708    36.7822
# 2709    99.6519
# 2710   -69.6423
# 2711   -72.8141
# 2712   -72.2460
# 2713   -63.4130
# 2714   124.1537
# 2715    57.5360
# 2716    25.2465
# 2717   122.9802
# 2718   -70.6640
# 2719   -70.2136
# 2720    76.8500
# 2721    58.0957
#
# [2722 rows x 9 columns]

# %%
#Replacing NaNs and floats in the "Speakers" column
df['Speakers'] = df['Speakers'].fillna(df["Speakers"].min()).astype(int)
df.Speakers
# Out:
# 0       7500000
# 1       5000000
# 2       4800000
# 3       4000000
# 4       3500000
# 5       3500000
# 6       3000000
# 7       2713790
# 8       2600000
# 9       2300000
# 10      2003783
# 11      2000000
# 12      2000000
# 13      2000000
# 14      2000000
# 15      2000000
# 16      1751489
# 17      1750000
# 18      1722768
# 19      1700000
# 20      1500000
# 21      1500000
# 22      1500000
# 23      1379727
# 24      1331844
# 25      1325382
# 26      1250000
# 27      1196639
# 28      1115000
# 29      1000000
#          ...
# 2692          0
# 2693          0
# 2694          0
# 2695          0
# 2696          0
# 2697          0
# 2698          0
# 2699          0
# 2700          0
# 2701          0
# 2702          0
# 2703          0
# 2704          0
# 2705          0
# 2706          0
# 2707          0
# 2708          0
# 2709          0
# 2710          0
# 2711          0
# 2712          0
# 2713          0
# 2714          0
# 2715          0
# 2716          0
# 2717          0
# 2718          0
# 2719          0
# 2720          0
# 2721          0
# Name: Speakers, Length: 2722, dtype: int64

# %%
#replacing categorical values in the "Endangerment" column to numerical ones
print(df.Endangerment.head())

labels = ['Vulnerable' ,'Definitely endangered' , 'Severely endangered', 'Critically endangered', 'Extinct']
label_to_enc = {'Vulnerable':0 ,'Definitely endangered':1 , 'Severely endangered':2, 
                'Critically endangered':3, 'Extinct':4}
enc_to_label = {value: key for key, value in label_to_enc.items()}
#print(enc_to_label)

#Creating a new column with encoded endagerment levels
df['Endangerment_enc'] = df.Endangerment.map(label_to_enc)
# Out:
# 0               Vulnerable
# 1               Vulnerable
# 2               Vulnerable
# 3               Vulnerable
# 4    Definitely endangered
# Name: Endangerment, dtype: object

# %%
df
# Out:
#         ID                                    Language  \
# 0     1022                               South Italian
# 1     1023                                    Sicilian
# 2      383                                   Low Saxon
# 3      335                                  Belarusian
# 4      382                                     Lombard
# 5      405                                      Romani
# 6     2211                            Yiddish (Israel)
# 7     1586                                       Gondi
# 8     1020                        Limburgian-Ripuarian
# 9     1943                 Quechua of Southern Bolivia
# 10    1565                                     Kumaoni
# 11     755                                      Aymara
# 12     349                            Emilian-Romagnol
# 13     399                                 Piedmontese
# 14    1021                                     Venetan
# 15    1985                                      Zazaki
# 16    1591                               Kurux (India)
# 17    2065                                     Tamajeq
# 18    1585                                        Tulu
# 19    1556                                      Kangdi
# 20     410                                       Scots
# 21    1026                                      Torlak
# 22    1476                                West Flemish
# 23     334                                     Bashkir
# 24    1067                                     Chechen
# 25     338                                     Chuvash
# 26    1227                                     Meithei
# 27    1114                                      Tamang
# 28    1013                            Quechua of Cuzco
# 29    1024                              Eastern Slovak
# ...    ...                                         ...
# 2692     3                                    Tasnusit
# 2693  1059                                         Tat
# 2694  1495                                        Tati
# 2695  2012                                      Tatuyo
# 2696   457                                        Tazy
# 2697  2458                                     Tempuan
# 2698  2188                                 Toba-Maskoy
# 2699   447                                      Tolcha
# 2700  2182                         Touggourt Tamazight
# 2701  2009                           Tucano (Colombia)
# 2702  2453              Tunisian Judeo-Arabic (Israel)
# 2703  2391                          Tuscarora (Canada)
# 2704  2013                           Tuyuca (Colombia)
# 2705  2192                               Udi (Georgia)
# 2706   280                                       Unami
# 2707  2392                       Upper Tanana (Canada)
# 2708  1336                                        Urum
# 2709  2475                                          Wa
# 2710  2014                 Wanano / Kotiria (Colombia)
# 2711  2393                    Western Abenaki (Canada)
# 2712   283  Western Abenaki (United States of America)
# 2713  2093                                       Wichi
# 2714  1971                                     Yaeyama
# 2715  1365                                  Yazva Komi
# 2716   428                            Yiddish (Europe)
# 2717  1972                                    Yonaguni
# 2718  2018                                      Yucuna
# 2719  2015                           Yurutí (Colombia)
# 2720  2716                                   Zangskari
# 2721  2177                                     Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# 7                                                 India
# 8                         Germany, Belgium, Netherlands
# 9                      Bolivia (Plurinational State of)
# 10                                         India, Nepal
# 11        Bolivia (Plurinational State of), Chile, Peru
# 12                                    Italy, San Marino
# 13                                                Italy
# 14                             Croatia, Italy, Slovenia
# 15                                               Turkey
# 16                                                India
# 17                                                Niger
# 18                                                India
# 19                                                India
# 20    United Kingdom of Great Britain and Northern I...
# 21    Albania, Bulgaria, The former Yugoslav Republi...
# 22                         Belgium, France, Netherlands
# 23                                   Russian Federation
# 24                                   Russian Federation
# 25                                   Russian Federation
# 26                                                India
# 27                                         India, Nepal
# 28                                                 Peru
# 29                                    Slovakia, Ukraine
# ...                                                 ...
# 2692                                            Algeria
# 2693                                         Azerbaijan
# 2694                         Iran (Islamic Republic of)
# 2695                                           Colombia
# 2696                                 Russian Federation
# 2697                                           Cambodia
# 2698                                           Paraguay
# 2699                                              India
# 2700                                            Algeria
# 2701                                           Colombia
# 2702                                             Israel
# 2703                                             Canada
# 2704                                           Colombia
# 2705                                            Georgia
# 2706                           United States of America
# 2707                                             Canada
# 2708               Georgia, Russian Federation, Ukraine
# 2709                                            Myanmar
# 2710                                           Colombia
# 2711                                             Canada
# 2712                           United States of America
# 2713        Argentina, Bolivia (Plurinational State of)
# 2714                                              Japan
# 2715                                 Russian Federation
# 2716  Germany, Austria, Belarus, Belgium, Denmark, E...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# 2720                                    India, Pakistan
# 2721                                               Oman
#
#                                            Country code  \
# 0                                                   ITA
# 1                                                   ITA
# 2                               DEU, DNK, NLD, POL, RUS
# 3                          BRB, LVA, LTU, POL, RUS, UKR
# 4                                              ITA, CHE
# 5     ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, F...
# 6                                                   ISR
# 7                                                   IND
# 8                                         DEU, BEL, NLD
# 9                                                   BOL
# 10                                             IND, NPL
# 11                                        BOL, CHL, PER
# 12                                             ITA, SMR
# 13                                                  ITA
# 14                                        HRV, ITA, SVN
# 15                                                  TUR
# 16                                                  IND
# 17                                                  NER
# 18                                                  IND
# 19                                                  IND
# 20                                                  GBR
# 21                              ALB, BGR, MKD, ROU, SRB
# 22                                        BEL, FRA, NLD
# 23                                                  RUS
# 24                                                  RUS
# 25                                                  RUS
# 26                                                  IND
# 27                                             IND, NPL
# 28                                                  PER
# 29                                             SVK, UKR
# ...                                                 ...
# 2692                                                DZA
# 2693                                                AZE
# 2694                                                IRN
# 2695                                                COL
# 2696                                                RUS
# 2697                                                KHM
# 2698                                                PRY
# 2699                                                IND
# 2700                                                DZA
# 2701                                                COL
# 2702                                                ISR
# 2703                                                CAN
# 2704                                                COL
# 2705                                                GEO
# 2706                                                USA
# 2707                                                CAN
# 2708                                      GEO, RUS, UKR
# 2709                                                MMR
# 2710                                                COL
# 2711                                                CAN
# 2712                                                USA
# 2713                                           ARG, BOL
# 2714                                                JPN
# 2715                                                RUS
# 2716  DEU, AUT, BRB, BEL, DNK, EST, FIN, FRA, HUN, I...
# 2717                                                JPN
# 2718                                                COL
# 2719                                                COL
# 2720                                           IND, PAK
# 2721                                                OMN
#
#                Endangerment  \
# 0                Vulnerable
# 1                Vulnerable
# 2                Vulnerable
# 3                Vulnerable
# 4     Definitely endangered
# 5     Definitely endangered
# 6     Definitely endangered
# 7                Vulnerable
# 8                Vulnerable
# 9                Vulnerable
# 10               Vulnerable
# 11               Vulnerable
# 12    Definitely endangered
# 13    Definitely endangered
# 14               Vulnerable
# 15               Vulnerable
# 16               Vulnerable
# 17               Vulnerable
# 18               Vulnerable
# 19    Definitely endangered
# 20               Vulnerable
# 21               Vulnerable
# 22               Vulnerable
# 23               Vulnerable
# 24               Vulnerable
# 25               Vulnerable
# 26               Vulnerable
# 27               Vulnerable
# 28               Vulnerable
# 29               Vulnerable
# ...                     ...
# 2692    Severely endangered
# 2693    Severely endangered
# 2694  Definitely endangered
# 2695  Definitely endangered
# 2696    Severely endangered
# 2697    Severely endangered
# 2698    Severely endangered
# 2699                Extinct
# 2700    Severely endangered
# 2701             Vulnerable
# 2702    Severely endangered
# 2703  Critically endangered
# 2704  Definitely endangered
# 2705    Severely endangered
# 2706                Extinct
# 2707  Critically endangered
# 2708  Definitely endangered
# 2709    Severely endangered
# 2710  Definitely endangered
# 2711  Critically endangered
# 2712                Extinct
# 2713             Vulnerable
# 2714    Severely endangered
# 2715    Severely endangered
# 2716  Definitely endangered
# 2717    Severely endangered
# 2718  Definitely endangered
# 2719  Definitely endangered
# 2720  Definitely endangered
# 2721  Critically endangered
#
#                                         Alternate names  Speakers  Latitude  \
# 0     Neapolitan; Neapolitan-Calabrese; неаполитанск...   7500000   40.9798
# 1                                                   NaN   5000000   37.4399
# 2     Low German, Niedersächsisch, Nedersaksisch, Ni...   4800000   53.4029
# 3                                                   NaN   4000000   53.9560
# 4                                                   NaN   3500000   45.7215
# 5                                    sinti, vlax,  calò   3500000   46.3165
# 6                                          Judeo-German   3000000   32.0833
# 7     Gondi; Gaudi; Gondiva; Gondwadi; Goondile; Gou...   2713790   19.5804
# 8                Colognian (dialect; in German: Kölsch)   2600000   50.7781
# 9                                                   NaN   2300000  -18.0675
# 10           Kumauni; Kamaoni; Kumau; Kumawani; Kumgoni   2003783   29.4778
# 11                   Aimara, Jaqi Aru, Southern Aymara.   2000000  -16.5835
# 12                                                  NaN   2000000   44.1270
# 13                                                  NaN   2000000   45.2013
# 14                                                  NaN   2000000   45.4601
# 15                               Zaza; Dimli; Kirmanjki   2000000   38.8824
# 16                                        Kurukh; Oraon   1751489   22.1467
# 17                                                  NaN   1750000   17.2352
# 18       Tuluva Bhasa; Tullu; Thulu; Tal; Tilu; Thalu\n   1722768   12.0178
# 19    Dogaryali; Dogri Pahari;  Tokkaru; Dogri-Kangr...   1700000   32.4356
# 20        Lallans; Northumbrian (local name in England)   1500000   56.2189
# 21             Shop; dialects: Goran, Janjev, Krashovan   1500000   42.9644
# 22                  Western Flemish; Zeelandic (Zeêuws)   1500000   51.0275
# 23                                             Bashkort   1379727   54.7309
# 24                                                  NaN   1331844   43.1971
# 25                                                  NaN   1325382   56.1394
# 26                                     Manipuri, Meitei   1250000   24.7667
# 27                     तामाङ; तामाङ्ग; Murmi (obsolete)   1196639   27.7365
# 28                                 Quechua Cuzco-Collao   1115000  -13.4537
# 29                                                  NaN   1000000   48.8068
# ...                                                 ...       ...       ...
# 2692  Tamazight, Berbere du Beni Snous, Ayt Snous, C...         0   34.6230
# 2693                                                NaN         0   41.3438
# 2694                      Tātī; Azari; Āẕarī; Takestani         0   38.2036
# 2695                                                NaN         0    0.4174
# 2696                                                Taz         0   43.9236
# 2697                                                NaN         0   13.7238
# 2698                                                NaN         0  -21.5578
# 2699                                                NaN         0   29.9333
# 2700  Righia, Chelha, Shelha\nGeneric term of Tamazight         0   33.0777
# 2701                                             Tukáno         0    0.6921
# 2702                        l'arabe des juifs tunisiens         0   32.0779
# 2703                                                NaN         0   43.0720
# 2704                                             Tuyúka         0    0.3515
# 2705                                                NaN         0   41.8905
# 2706                Delaware, Oklahoma Delaware, Lenape         0   39.1300
# 2707                                                NaN         0   62.3824
# 2708                                        Greek Tatar         0   47.0102
# 2709                                                NaN         0   21.8705
# 2710     Guanano, Kotiria is autodenomination in Brazil         0    1.0106
# 2711                                                NaN         0   46.0785
# 2712                                                NaN         0   43.0046
# 2713  Wichi, Weenhayek, Wichí Lhamtés Nocten , Wichí...         0  -22.0041
# 2714                                                NaN         0   24.3420
# 2715                                    Eastern Permyak         0   60.0348
# 2716                                       Judeo-German         0   53.3571
# 2717                                                NaN         0   24.4580
# 2718                                                NaN         0   -1.2633
# 2719                                                NaN         0    1.1370
# 2720                               Zangs-dkar, Z’angkar         0   34.0833
# 2721                                   Zidjali, Zadjali         0   23.4027
#
#       Longitude  Endangerment_enc
# 0       15.2490                 0
# 1       14.5019                 0
# 2       10.3601                 0
# 3       27.5756                 0
# 4        9.3273                 1
# 5       22.3681                 1
# 6       34.8333                 1
# 7       80.4418                 0
# 8        6.0864                 0
# 9      -65.7641                 0
# 10      79.8486                 0
# 11     -68.3020                 0
# 12      12.0739                 1
# 13       7.8662                 1
# 14      12.1948                 0
# 15      40.4846                 0
# 16      85.2758                 0
# 17       8.0859                 0
# 18      75.7067                 0
# 19      76.1242                 1
# 20      -3.7683                 0
# 21      22.1374                 0
# 22       3.0541                 0
# 23      55.9863                 0
# 24      45.7031                 0
# 25      47.2412                 0
# 26      93.8946                 0
# 27      85.6858                 0
# 28     -72.0098                 0
# 29      21.7968                 0
# ...         ...               ...
# 2692    -1.5614                 2
# 2693    48.6254                 2
# 2694    48.2519                 1
# 2695   -70.4882                 1
# 2696   134.7967                 2
# 2697   107.2038                 2
# 2698   -58.0064                 2
# 2699    80.0326                 4
# 2700     6.0671                 2
# 2701   -69.8291                 0
# 2702    34.8019                 2
# 2703   -80.0150                 3
# 2704   -70.2026                 1
# 2705    45.9130                 2
# 2706   -76.0253                 4
# 2707  -140.8984                 3
# 2708    36.7822                 1
# 2709    99.6519                 2
# 2710   -69.6423                 1
# 2711   -72.8141                 3
# 2712   -72.2460                 4
# 2713   -63.4130                 0
# 2714   124.1537                 2
# 2715    57.5360                 2
# 2716    25.2465                 1
# 2717   122.9802                 2
# 2718   -70.6640                 1
# 2719   -70.2136                 1
# 2720    76.8500                 1
# 2721    58.0957                 3
#
# [2722 rows x 10 columns]

# %%
#df.loc[df['name']=="journal title",'cost'].mean()
#df.groupby(['jounrl title colum'])['cost'].mean()
#dd= pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
##dd.plot.bar(stacked=True)
#pd.crosstab(dd.SessionId, data.Query).plot.barh(stacked=True)
#dd

# %%
#Saving all the countries in the list locations 
locations = df.Countries.str.split(',',len(df.Countries)).tolist() #returns a list
locations=[x for x in locations if str(x) != 'nan']
countries = []
locations
# Out:
# [['Italy'],
#  ['Italy'],
#  ['Germany', ' Denmark', ' Netherlands', ' Poland', ' Russian Federation'],
#  ['Belarus',
#   ' Latvia',
#   ' Lithuania',
#   ' Poland',
#   ' Russian Federation',
#   ' Ukraine'],
#  ['Italy', ' Switzerland'],
#  ['Albania',
#   ' Germany',
#   ' Austria',
#   ' Belarus',
#   ' Bosnia and Herzegovina',
#   ' Bulgaria',
#   ' Croatia',
#   ' Estonia',
#   ' Finland',
#   ' France',
#   ' Greece',
#   ' Hungary',
#   ' Italy',
#   ' Latvia',
#   ' Lithuania',
#   ' The former Yugoslav Republic of Macedonia',
#   ' Netherlands',
#   ' Poland',
#   ' Romania',
#   ' United Kingdom of Great Britain and Northern Ireland',
#   ' Russian Federation',
#   ' Slovakia',
#   ' Slovenia',
#   ' Switzerland',
#   ' Czech Republic',
#   ' Turkey',
#   ' Ukraine',
#   ' Serbia',
#   ' Montenegro'],
#  ['Israel'],
#  ['India'],
#  ['Germany', ' Belgium', ' Netherlands'],
#  ['Bolivia (Plurinational State of)'],
#  ['India', ' Nepal'],
#  ['Bolivia (Plurinational State of)', ' Chile', ' Peru'],
#  ['Italy', ' San Marino'],
#  ['Italy'],
#  ['Croatia', ' Italy', ' Slovenia'],
#  ['Turkey'],
#  ['India'],
#  ['Niger'],
#  ['India'],
#  ['India'],
#  ['United Kingdom of Great Britain and Northern Ireland'],
#  ['Albania',
#   ' Bulgaria',
#   ' The former Yugoslav Republic of Macedonia',
#   ' Romania',
#   ' Serbia'],
#  ['Belgium', ' France', ' Netherlands'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['India'],
#  ['India', ' Nepal'],
#  ['Peru'],
#  ['Slovakia', ' Ukraine'],
#  ['France', ' Italy', ' Monaco'],
#  ['Hungary', ' Poland', ' Romania', ' Slovakia', ' Ukraine'],
#  ['Azerbaijan', ' Iran (Islamic Republic of)'],
#  ['India'],
#  ['India'],
#  ['India'],
#  ['Italy'],
#  ['Guatemala'],
#  ['Peru'],
#  ['Nepal'],
#  ['Myanmar', ' Thailand'],
#  ['Belarus', ' Poland', ' Ukraine'],
#  ['Mali'],
#  ['Russian Federation'],
#  ['India'],
#  ['United Kingdom of Great Britain and Northern Ireland'],
#  ['India', ' Nepal'],
#  ['Guatemala'],
#  ['Belgium', ' France'],
#  ['Bangladesh', ' India'],
#  ['Spain', ' France'],
#  ['Russian Federation', ' Turkey'],
#  ['India'],
#  ['Italy'],
#  ['Peru'],
#  ['Belgium', ' France', ' Luxembourg'],
#  ['India'],
#  ['Georgia', ' Russian Federation'],
#  ['India'],
#  ['Russian Federation'],
#  ['Albania',
#   ' Bulgaria',
#   ' Greece',
#   ' The former Yugoslav Republic of Macedonia',
#   ' Serbia'],
#  ['Iran (Islamic Republic of)', ' Pakistan', ' Afghanistan'],
#  ['France'],
#  ['Azerbaijan', ' Russian Federation'],
#  ['India'],
#  ['Nepal'],
#  ['Guatemala'],
#  ['Russian Federation'],
#  ['Mexico'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Guatemala'],
#  ['India'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['India'],
#  ['Israel'],
#  ['China'],
#  ['France'],
#  ['Italy'],
#  ['Chile'],
#  ['Mexico'],
#  ['Germany', ' Belgium', ' France', ' Luxembourg'],
#  ['Nepal'],
#  ['China'],
#  ['Georgia'],
#  ['Netherlands'],
#  ['Nepal'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Russian Federation'],
#  ['Iraq',
#   ' Israel',
#   ' Jordan',
#   ' The former Yugoslav Republic of Macedonia',
#   ' Russian Federation',
#   ' Syrian Arab Republic',
#   ' Turkey'],
#  ['Russian Federation'],
#  ['India'],
#  ['India'],
#  ['India', ' Nepal'],
#  ['Israel'],
#  ['Ukraine'],
#  ['Armenia',
#   ' Georgia',
#   ' Greece',
#   ' Russian Federation',
#   ' Turkey',
#   ' Ukraine'],
#  ['Ecuador'],
#  ['China'],
#  ['China', ' Kyrgyzstan', ' Mongolia'],
#  ['India'],
#  ['Nigeria'],
#  ['France'],
#  ['Spain', ' France'],
#  ['China'],
#  ['India'],
#  ['India'],
#  ['India'],
#  ['China', ' Mongolia', ' Russian Federation'],
#  ['Libyan Arab Jamahiriya'],
#  ['Armenia',
#   ' Iran (Islamic Republic of)',
#   ' Iraq',
#   ' Syrian Arab Republic',
#   ' Turkey'],
#  ['India'],
#  ['Pakistan'],
#  ['Pakistan'],
#  ['Russian Federation'],
#  ['France', ' Italy'],
#  ['France'],
#  ['Nigeria'],
#  ['India'],
#  ['India'],
#  ['Iran (Islamic Republic of)'],
#  ['India'],
#  ['Russian Federation'],
#  ['Iraq', ' Lebanon', ' Syrian Arab Republic'],
#  ['Cambodia'],
#  ['Bhutan', ' China', ' India'],
#  ['India'],
#  ['Republic of Moldova', ' Ukraine'],
#  ['India'],
#  ['China', ' India'],
#  ['India'],
#  ['India'],
#  ['Panama'],
#  ['India'],
#  ['France', ' Italy'],
#  ['Bhutan'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Spain', ' Portugal'],
#  ['Latvia', ' Russian Federation'],
#  ['France'],
#  ['India'],
#  ['Algeria'],
#  ['China', ' India', ' Nepal'],
#  ['India'],
#  ['Guatemala'],
#  ['India'],
#  ['India'],
#  ['Georgia', ' Turkey'],
#  ['Russian Federation'],
#  ['India'],
#  ['Georgia', ' Russian Federation', ' Turkey'],
#  ['India'],
#  ['India'],
#  ['United States of America'],
#  ['Italy'],
#  ['Algeria'],
#  ['India'],
#  ['Mexico'],
#  ['India'],
#  ['India'],
#  ['China', ' India'],
#  ['China'],
#  ['India'],
#  ['Mexico'],
#  ['Ukraine'],
#  ['China'],
#  ['France', ' Italy', ' Switzerland'],
#  ['Italy'],
#  ['Argentina'],
#  ['Oman', ' Yemen'],
#  ['Nicaragua'],
#  ['China'],
#  ['Bolivia (Plurinational State of)'],
#  ['Kenya', ' United Republic of Tanzania'],
#  ['Honduras'],
#  ['Colombia'],
#  ['India'],
#  ['Tajikistan', ' Afghanistan'],
#  ['Russian Federation'],
#  ['Guatemala'],
#  ['India'],
#  ['Russian Federation'],
#  ['Sudan'],
#  ['Ecuador'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Pakistan'],
#  ['Mexico'],
#  ['India'],
#  ['India'],
#  ['Guatemala'],
#  ['Guatemala'],
#  ['Ethiopia'],
#  ['India'],
#  ['Italy'],
#  ['Iran (Islamic Republic of)'],
#  ['Colombia'],
#  ['Argentina'],
#  ['Georgia'],
#  ["Lao People's Democratic Republic", ' Viet Nam'],
#  ['Algeria'],
#  ['Yemen'],
#  ['China', ' Pakistan', ' Tajikistan', ' Afghanistan'],
#  ['Bangladesh', ' India'],
#  ['Sudan'],
#  ['New Zealand'],
#  ["Lao People's Democratic Republic"],
#  ['India', ' Pakistan'],
#  ['India'],
#  ['Italy'],
#  ['Bangladesh'],
#  ['Guatemala'],
#  ['Guam (U.S.A.)'],
#  ['Peru'],
#  ['India'],
#  ['Panama'],
#  ['India'],
#  ['India'],
#  ['India'],
#  ['Faroe Islands'],
#  ['China'],
#  ['Pakistan'],
#  ['Guatemala'],
#  ['India'],
#  ['United Kingdom of Great Britain and Northern Ireland'],
#  ['Mexico'],
#  ['Costa Rica'],
#  ['Poland'],
#  ['Russian Federation'],
#  ['India'],
#  ['Greece'],
#  ['Russian Federation'],
#  ['China', ' Mongolia'],
#  ['Bhutan', ' China', ' India'],
#  ['Viet Nam'],
#  ['India'],
#  ['China'],
#  ['India'],
#  ['Ecuador'],
#  ['Yemen'],
#  ['Russian Federation'],
#  ['Romania'],
#  ['Syrian Arab Republic', ' Turkey'],
#  ['Estonia', ' Russian Federation'],
#  ['Greenland (Kingdom of Denmark)'],
#  ['Turkey'],
#  ['United Republic of Tanzania'],
#  ['Algeria'],
#  ['Mexico'],
#  ['India'],
#  ['India'],
#  ['China'],
#  ['Viet Nam'],
#  ['China'],
#  ['Sudan'],
#  ['Ecuador'],
#  ['Nepal'],
#  ['Ireland', ' United Kingdom of Great Britain and Northern Ireland'],
#  ['Nigeria'],
#  ['Mexico'],
#  ['Lesotho'],
#  ['Cook Islands'],
#  ['Iran (Islamic Republic of)'],
#  ['Kazakhstan', ' Kyrgyzstan'],
#  ['India'],
#  ['Senegal'],
#  ['Nepal'],
#  ['Argentina', ' Bolivia (Plurinational State of)'],
#  ['India'],
#  ['Bhutan'],
#  ['Sudan'],
#  ['India'],
#  ['Myanmar'],
#  ['Thailand'],
#  ['Peru'],
#  ['Ecuador'],
#  ['India'],
#  ['Niger'],
#  ['Peru'],
#  ['India'],
#  ['Sudan'],
#  ["Lao People's Democratic Republic"],
#  ['Mexico'],
#  ['India'],
#  ['Russian Federation'],
#  ['Nepal'],
#  ['Mexico'],
#  ['China'],
#  ['Guatemala'],
#  ['Mexico'],
#  ['Switzerland'],
#  ['India'],
#  ['India'],
#  ['India'],
#  ['Ecuador'],
#  ['Brazil', ' Colombia', ' Peru'],
#  ['Peru'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Guatemala'],
#  ['India'],
#  ['India'],
#  ['Mexico'],
#  ['Nepal'],
#  ['India'],
#  ['Mexico'],
#  ['Indonesia'],
#  ['Nepal'],
#  ['India'],
#  ['Russian Federation', ' Turkey'],
#  ['India'],
#  ['China'],
#  ['Indonesia'],
#  ['Bhutan'],
#  ['Austria', ' Hungary', ' Slovakia'],
#  ['Iran (Islamic Republic of)'],
#  ['Israel'],
#  ['Nepal'],
#  ['Italy'],
#  ['Bhutan', ' India', ' Nepal'],
#  ['China'],
#  ['Myanmar', ' Thailand'],
#  ['Sudan'],
#  ['China'],
#  ['Finland', ' Norway', ' Russian Federation', ' Sweden'],
#  ['Peru'],
#  ['Ecuador'],
#  ['Tajikistan', ' Afghanistan'],
#  ['India'],
#  ['Indonesia'],
#  ['Algeria'],
#  ['Argentina'],
#  ['Russian Federation'],
#  ['Croatia', ' Serbia'],
#  ['China'],
#  ['Russian Federation'],
#  ['Azerbaijan', ' Russian Federation'],
#  ['Pakistan'],
#  ['India'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Nepal'],
#  ['India'],
#  ['Mexico'],
#  ['Mexico'],
#  ['China'],
#  ['Mexico'],
#  ['Nepal'],
#  ['Senegal'],
#  ['India'],
#  ['Romania', ' Serbia'],
#  ['Romania'],
#  ['India'],
#  ['China'],
#  ['Honduras'],
#  ['Finland', ' Russian Federation'],
#  ["Lao People's Democratic Republic", ' Thailand'],
#  ['United States of America'],
#  ['Morocco'],
#  ['Azerbaijan', ' Russian Federation'],
#  ['Guyana', ' Venezuela (Bolivarian Republic of)'],
#  ['Nepal'],
#  ['China'],
#  ['Russian Federation'],
#  ['Colombia'],
#  ['India'],
#  ['Iran (Islamic Republic of)', ' Iraq'],
#  ['India'],
#  ['India'],
#  ['Panama'],
#  ['Guinea-Bissau'],
#  ['India'],
#  ['India'],
#  ['Nigeria'],
#  ['China'],
#  ['Sudan'],
#  ['Iran (Islamic Republic of)'],
#  ['Iran (Islamic Republic of)'],
#  ['Iran (Islamic Republic of)'],
#  ['Canada'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Mexico'],
#  ['China'],
#  ['India'],
#  ['Thailand'],
#  ['Bhutan'],
#  ['Bulgaria', ' Romania'],
#  ['Nepal'],
#  ['Italy'],
#  ['Brazil'],
#  ['Finland', ' Russian Federation'],
#  ['India'],
#  ['India'],
#  ['Ukraine'],
#  ['India'],
#  ['Guyana', ' Venezuela (Bolivarian Republic of)'],
#  ['Algeria'],
#  ['China'],
#  ['Syrian Arab Republic'],
#  ['Tajikistan'],
#  ['Myanmar'],
#  ['Botswana'],
#  ['Germany'],
#  ['India'],
#  ['India'],
#  ['Brazil'],
#  ['Pakistan', ' Afghanistan'],
#  ['Nepal'],
#  ['Brazil'],
#  ['Mexico'],
#  ['Iran (Islamic Republic of)'],
#  ['Senegal'],
#  ['Senegal'],
#  ['India'],
#  ['Libyan Arab Jamahiriya'],
#  ['Canada'],
#  ['India'],
#  ['Ethiopia'],
#  ['India'],
#  ['Peru'],
#  ['Uganda'],
#  ['Russian Federation'],
#  ['China'],
#  ['Viet Nam'],
#  ['Iran (Islamic Republic of)'],
#  ['Bhutan'],
#  ['China'],
#  ['India'],
#  ['Nigeria'],
#  ['Nepal'],
#  ['China'],
#  ["Lao People's Democratic Republic"],
#  ['Ethiopia'],
#  ['China'],
#  ['Thailand'],
#  ['Brazil'],
#  ['India'],
#  ['China'],
#  ['Thailand'],
#  ['United States of America'],
#  ['United States of America'],
#  ['China'],
#  ['China'],
#  ['Malaysia'],
#  ['Sudan'],
#  ['Egypt'],
#  ['Algeria'],
#  ['Algeria'],
#  ['Indonesia'],
#  ['Colombia'],
#  ['Nepal'],
#  ['India'],
#  ['French Polynesia (France)'],
#  ['Sudan'],
#  ['Belize'],
#  ['Nepal'],
#  ['Bangladesh', ' India'],
#  ['Brazil'],
#  ['Niue'],
#  ['Indonesia'],
#  ['Senegal'],
#  ['Brazil'],
#  ['Indonesia'],
#  ['India'],
#  ['Guinea'],
#  ['Sudan'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Belize'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Guinea'],
#  ['Indonesia'],
#  ['India'],
#  ['Russian Federation'],
#  ['Viet Nam'],
#  ['India'],
#  ['China'],
#  ['China'],
#  ['China'],
#  ['Indonesia'],
#  ['Indonesia'],
#  ['Russian Federation'],
#  ['Mexico'],
#  ['Guatemala'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Ethiopia', ' Sudan'],
#  ['Ghana'],
#  ['Guatemala'],
#  ['China', ' India'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Peru'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Tuvalu'],
#  ['Colombia'],
#  ['Senegal'],
#  ['Nepal'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Papua New Guinea'],
#  ['Indonesia'],
#  ['Nepal'],
#  ['Senegal'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Italy'],
#  ['Spain'],
#  ['China'],
#  ['Uzbekistan'],
#  ['China'],
#  ['United Republic of Tanzania'],
#  ['Peru'],
#  ['United States of America'],
#  ['Sweden'],
#  ['Colombia', ' Peru'],
#  ['Israel'],
#  ['Chad'],
#  ['Russian Federation'],
#  ['Senegal'],
#  ['Azerbaijan'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Bhutan'],
#  ['India'],
#  ['China'],
#  ['Bolivia (Plurinational State of)'],
#  ['India'],
#  ['India'],
#  ['Brazil'],
#  ['Nigeria'],
#  ['Germany'],
#  ['Russian Federation'],
#  ['Thailand'],
#  ['Bhutan'],
#  ['Malaysia'],
#  ['Sudan'],
#  ['China'],
#  ['China'],
#  ['Indonesia'],
#  ['China'],
#  ['Tunisia'],
#  ['China'],
#  ['Sudan'],
#  ['Malaysia'],
#  ['Russian Federation', ' Turkmenistan'],
#  ['United Republic of Tanzania'],
#  ['Colombia'],
#  ['Senegal'],
#  ['Guatemala'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Pakistan', ' Afghanistan'],
#  ['China', ' India', ' Myanmar'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Canada'],
#  ['Canada'],
#  ['Viet Nam'],
#  ['Nepal'],
#  ['Indonesia'],
#  ['Indonesia'],
#  ['China', ' India'],
#  ['Nicaragua'],
#  ['United States of America'],
#  ['Belize'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Ethiopia'],
#  ['Pakistan'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Chad'],
#  ['Mexico'],
#  ['Canada'],
#  ['United States of America'],
#  ['Ethiopia'],
#  ['French Polynesia (France)'],
#  ['Sudan'],
#  ['Sudan'],
#  ['Japan'],
#  ['Colombia'],
#  ['Sudan'],
#  ['China'],
#  ['Bhutan'],
#  ['Paraguay'],
#  ['Brazil'],
#  ['United States of America'],
#  ['Ecuador'],
#  ['India'],
#  ['China'],
#  ['Malaysia'],
#  ['Sudan'],
#  ['Peru'],
#  ['China'],
#  ['Peru'],
#  ['Mexico'],
#  ['Burkina Faso'],
#  ['Guyana'],
#  ['Russian Federation'],
#  ['Costa Rica'],
#  ['Colombia'],
#  ['Israel'],
#  ['Mexico'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Brazil'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Peru'],
#  ['India'],
#  ['Iran (Islamic Republic of)'],
#  ['Kenya'],
#  ['China'],
#  ['Iran (Islamic Republic of)'],
#  ['China'],
#  ['Russian Federation'],
#  ['Iran (Islamic Republic of)'],
#  ['Iran (Islamic Republic of)'],
#  ['Uzbekistan', ' Tajikistan', ' Afghanistan'],
#  ['United Republic of Tanzania'],
#  ['Iran (Islamic Republic of)'],
#  ['Iran (Islamic Republic of)'],
#  ['Brazil'],
#  ['Guyana'],
#  ['Central African Republic', ' Democratic Republic of the Congo', ' Sudan'],
#  ['China'],
#  ['Guatemala'],
#  ['Ethiopia'],
#  ['Micronesia (Federated States of)', ' Nauru'],
#  ['Panama'],
#  ['Mexico'],
#  ['Canada'],
#  ['Canada'],
#  ['Mexico'],
#  ['China', ' India'],
#  ['United States of America'],
#  ['Mexico'],
#  ['Ethiopia'],
#  ['Sudan'],
#  ['China'],
#  ['Sudan'],
#  ['Russian Federation'],
#  ['Canada'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Ethiopia'],
#  ['Bolivia (Plurinational State of)'],
#  ['Sudan'],
#  ['Russian Federation'],
#  ['Nepal'],
#  ['Sudan'],
#  ['Brazil'],
#  ['Russian Federation'],
#  ['Mexico'],
#  ['Canada'],
#  ['Sudan'],
#  ['Indonesia'],
#  ['Brazil'],
#  ['Nigeria'],
#  ['Brazil'],
#  ['Myanmar', ' Thailand'],
#  ['Nauru'],
#  ['Brazil'],
#  ['Afghanistan'],
#  ['Peru'],
#  ['Libyan Arab Jamahiriya'],
#  ['China', ' India'],
#  ['Russian Federation'],
#  ['United States of America'],
#  ['Brazil'],
#  ['Tajikistan'],
#  ['Nepal'],
#  ['Micronesia (Federated States of)'],
#  ['Brazil', ' Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Guyana', ' Venezuela (Bolivarian Republic of)'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Canada'],
#  ['Guatemala'],
#  ['Costa Rica'],
#  ['Senegal'],
#  ['Senegal'],
#  ['Viet Nam'],
#  ['Mexico'],
#  ['Pakistan'],
#  ['Bangladesh'],
#  ['Pakistan'],
#  ['Mexico'],
#  ['Bolivia (Plurinational State of)'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Sudan'],
#  ["Lao People's Democratic Republic", ' Myanmar', ' Thailand'],
#  ['China'],
#  ['Russian Federation'],
#  ['Ethiopia'],
#  ['Colombia'],
#  ['Tajikistan'],
#  ['China', ' India'],
#  ['Bhutan'],
#  ['United States of America'],
#  ['Colombia'],
#  ['China'],
#  ['Indonesia'],
#  ['United Republic of Tanzania'],
#  ['India'],
#  ['Bolivia (Plurinational State of)'],
#  ['Sweden'],
#  ['United States of America'],
#  ['Nigeria'],
#  ['Oman'],
#  ['Pakistan'],
#  ['United Republic of Tanzania'],
#  ['China'],
#  ['Oman'],
#  ['Namibia'],
#  ['India'],
#  ['Algeria'],
#  ['Viet Nam'],
#  ['China'],
#  ['Cook Islands'],
#  ['Greece', ' The former Yugoslav Republic of Macedonia'],
#  ['India'],
#  ['China'],
#  ['Viet Nam'],
#  ['Italy'],
#  ['Morocco'],
#  ['China'],
#  ['Indonesia'],
#  ['Guyana'],
#  ['India'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['India'],
#  ['India'],
#  ['Azerbaijan'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Nepal'],
#  ['Russian Federation'],
#  ['Colombia'],
#  ['Nepal'],
#  ['Mexico'],
#  ['China'],
#  ['Canada'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Nepal'],
#  ['China'],
#  ['Canada'],
#  ['Sudan'],
#  ['Peru'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Tokelau'],
#  ['Indonesia'],
#  ['Nepal'],
#  ['Canada'],
#  ['Ethiopia'],
#  ['Sudan'],
#  ['Ghana'],
#  ['Nepal'],
#  ['Cameroon', ' Equatorial Guinea'],
#  ['Congo', ' Gabon'],
#  ['Canada'],
#  ['Canada'],
#  ['Mexico'],
#  ['United States of America'],
#  ['India', ' Sudan'],
#  ['Guinea'],
#  ['Guinea'],
#  ['Russian Federation'],
#  ['India'],
#  ['Peru'],
#  ['Ecuador'],
#  ['China'],
#  ['China'],
#  ['Russian Federation'],
#  ['Guyana', ' Suriname'],
#  ['Israel'],
#  ["Lao People's Democratic Republic"],
#  ['Indonesia'],
#  ['Indonesia'],
#  ['China', ' Nepal'],
#  ['China'],
#  ['Botswana'],
#  ['Sudan'],
#  ['Brazil'],
#  ['Peru'],
#  ['Brazil'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['China'],
#  ['Mauritania'],
#  ['India'],
#  ['India'],
#  ['Guatemala'],
#  ['Viet Nam'],
#  ['Ghana'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Nepal'],
#  ['Bolivia (Plurinational State of)'],
#  ['India'],
#  ['China'],
#  ['Ethiopia'],
#  ['Papua New Guinea'],
#  ['Sudan'],
#  ['Guatemala'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Sudan'],
#  ['Myanmar'],
#  ['Colombia'],
#  ['United States of America'],
#  ['Myanmar'],
#  ['Sudan'],
#  ['Indonesia'],
#  ['Canada'],
#  ['Nigeria'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Senegal'],
#  ['Panama'],
#  ['Sudan'],
#  ['Ethiopia'],
#  ['Indonesia'],
#  ['Mexico'],
#  ['Belize'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Azerbaijan', ' Russian Federation'],
#  ['Libyan Arab Jamahiriya'],
#  ['Indonesia'],
#  ['Gabon', ' Equatorial Guinea'],
#  ['Indonesia'],
#  ['Kenya'],
#  ['Congo'],
#  ['India'],
#  ['Azerbaijan'],
#  ['Eritrea'],
#  ['Greenland (Kingdom of Denmark)'],
#  ['Russian Federation'],
#  ['Nigeria'],
#  ['India'],
#  ['Nigeria'],
#  ['Oman'],
#  ['Ethiopia'],
#  ['United States of America'],
#  ['Ghana'],
#  ['Micronesia (Federated States of)'],
#  ['Papua New Guinea'],
#  ['Cameroon'],
#  ['China'],
#  ['Nepal'],
#  ['Israel'],
#  ['Russian Federation'],
#  ['Argentina', ' Uruguay'],
#  ['United States of America'],
#  ['China', ' Russian Federation'],
#  ['Indonesia'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Argentina'],
#  ['Australia'],
#  ['Guinea'],
#  ['Fiji'],
#  ['Pakistan', ' Afghanistan'],
#  ['India'],
#  ['China'],
#  ['India'],
#  ['China'],
#  ['Micronesia (Federated States of)'],
#  ['Timor-Leste'],
#  ['Australia'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Canada'],
#  ['Brazil'],
#  ['United Kingdom of Great Britain and Northern Ireland'],
#  ['Nepal'],
#  ['Canada'],
#  ['Mexico'],
#  ['Russian Federation'],
#  ['Myanmar', ' Thailand'],
#  ['Brazil'],
#  ['China'],
#  ['China'],
#  ['Sudan'],
#  ['Bolivia (Plurinational State of)'],
#  ['India'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Angola'],
#  ['Sudan'],
#  ["Lao People's Democratic Republic", ' Viet Nam'],
#  ['Mexico'],
#  ['Brazil'],
#  ['Panama'],
#  ['Ecuador', ' Peru'],
#  ['Sudan'],
#  ['Mali'],
#  ['Peru'],
#  ['Chad'],
#  ['Azerbaijan'],
#  ['China'],
#  ['Myanmar'],
#  ['Bhutan'],
#  ['Australia'],
#  ['Peru'],
#  ['Micronesia (Federated States of)'],
#  ['Chile'],
#  ['India'],
#  ['Tajikistan'],
#  ['Tajikistan', ' Afghanistan'],
#  ['Malaysia'],
#  ['Malaysia'],
#  ['Thailand'],
#  ['Chad'],
#  ['Gabon'],
#  ['Guatemala'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Cameroon', ' Equatorial Guinea'],
#  ['Papua New Guinea'],
#  ['China'],
#  ['Viet Nam'],
#  ['Mexico'],
#  ['Canada'],
#  ['Chad'],
#  ['Brazil'],
#  ['Chad'],
#  ['Brazil'],
#  ['Malaysia'],
#  ['Peru'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Brazil'],
#  ['Australia'],
#  ['China'],
#  ['Costa Rica'],
#  ['India'],
#  ['Australia'],
#  ['Brazil'],
#  ['Australia'],
#  ['Afghanistan'],
#  ['Philippines'],
#  ['Nepal'],
#  ['Argentina'],
#  ['Ethiopia'],
#  ['India'],
#  ['Indonesia'],
#  ['China', ' India'],
#  ["Lao People's Democratic Republic"],
#  ['Pakistan'],
#  ['Brazil'],
#  ['Colombia'],
#  ['Nigeria'],
#  ['Brazil'],
#  ['Ethiopia'],
#  ['Indonesia'],
#  ['Libyan Arab Jamahiriya'],
#  ['Italy'],
#  ['Chile'],
#  ['Uganda'],
#  ['India'],
#  ['Nepal'],
#  ['French Guiana (France)'],
#  ['China', ' Mongolia', ' Russian Federation'],
#  ['Nigeria'],
#  ['Colombia'],
#  ['Russian Federation'],
#  ['India'],
#  ['Sudan'],
#  ['Norway', ' Sweden'],
#  ['India'],
#  ['Chad'],
#  ['India'],
#  ['Argentina'],
#  ['Indonesia'],
#  ['Thailand'],
#  ['China'],
#  ['Afghanistan'],
#  ['Viet Nam'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['India'],
#  ['Nepal'],
#  ['Canada', ' United States of America'],
#  ['Afghanistan'],
#  ['China'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['China'],
#  ['Chad'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['Algeria'],
#  ['China'],
#  ...]

# %%
#Number of languages in each category of endangerment levels 
df.Endangerment.value_counts()
# Out:
# Definitely endangered    680
# Vulnerable               628
# Critically endangered    607
# Severely endangered      554
# Extinct                  253
# Name: Endangerment, dtype: int64

# %%
df.sort_values(['Countries', 'Speakers'], ascending=True)
# Out:
#         ID                 Language  \
# 2657  2479                  Pashayi
# 1803  2483                   Tirahi
# 1648   148                   Moghol
# 1649  2198                Ningalami
# 1166   773                  Gambiri
# 1210  1498                Shumashti
# 947    281                   Ashkun
# 984   1851                    Munji
# 990   1572                   Prasun
# 1007   895                  Waigali
# 1009  2482      Wotapuri-Katarqalai
# 667   2299                  Parachi
# 2600   374         Judezmo (Europe)
# 60     331                Aromanian
# 21    1026                   Torlak
# 5      405                   Romani
# 2692     3                 Tasnusit
# 2700  2182      Touggourt Tamazight
# 999      2        Tamazight (Arzew)
# 721   2183                 Korandje
# 450   1289               Tagargrent
# 451   2162                 Tayurayt
# 399   1995                 Tacenwit
# 332   2181                 Tidikelt
# 250   2180                 Zenatiya
# 203   2163                 Taznatit
# 158    655        Tamahaq (Algeria)
# 144   1996                 Tamzabit
# 2385   126                     Kede
# 2402   124                    Kwadi
# ...    ...                      ...
# 874    326                    Yukpa
# 791   1981     Yanomami (Venezuela)
# 735    310                     Pume
# 739   1979      Yecuana (Venezuela)
# 495    683      Kari'ña (Venezuela)
# 497   1963       Piaroa (Venezuela)
# 2175   527          Iduh (Viet Nam)
# 2040  2230     Red Gelao (Viet Nam)
# 2048  2231   White Gelao (Viet Nam)
# 1652  2250                 Nung Ven
# 1532   524   Green Gelao (Viet Nam)
# 1386  2242                   Laghuu
# 1387   532           Laha (Lao Cai)
# 1388  2197            Laha (Son La)
# 1036  2239                    Côông
# 985   2247                    Nguon
# 925    541          Mang (Viet Nam)
# 797   2196          Khang Quang Lam
# 722    531                    Lachi
# 728   2243        Mo'ang (Viet Nam)
# 686   2248        Baheng (Viet Nam)
# 562   2244         Phula (Viet Nam)
# 479   2238                     Chru
# 427   2246                    Chrau
# 255   2240        Cosung (Viet Nam)
# 237   2229             Eastern Cham
# 1223  2190  Zenaga (Western Sahara)
# 242   1949                  Soqotri
# 204   2179                   Razihi
# 405   1680                     Boro
#
#                                               Countries  \
# 2657                                        Afghanistan
# 1803                                        Afghanistan
# 1648                                        Afghanistan
# 1649                                        Afghanistan
# 1166                                        Afghanistan
# 1210                                        Afghanistan
# 947                                         Afghanistan
# 984                                         Afghanistan
# 990                                         Afghanistan
# 1007                                        Afghanistan
# 1009                                        Afghanistan
# 667                                         Afghanistan
# 2600  Albania, Algeria, Bosnia and Herzegovina, Bulg...
# 60    Albania, Bulgaria, Greece, The former Yugoslav...
# 21    Albania, Bulgaria, The former Yugoslav Republi...
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 2692                                            Algeria
# 2700                                            Algeria
# 999                                             Algeria
# 721                                             Algeria
# 450                                             Algeria
# 451                                             Algeria
# 399                                             Algeria
# 332                                             Algeria
# 250                                             Algeria
# 203                                             Algeria
# 158                                             Algeria
# 144                                             Algeria
# 2385                                             Angola
# 2402                                             Angola
# ...                                                 ...
# 874                  Venezuela (Bolivarian Republic of)
# 791                  Venezuela (Bolivarian Republic of)
# 735                  Venezuela (Bolivarian Republic of)
# 739                  Venezuela (Bolivarian Republic of)
# 495                  Venezuela (Bolivarian Republic of)
# 497                  Venezuela (Bolivarian Republic of)
# 2175                                           Viet Nam
# 2040                                           Viet Nam
# 2048                                           Viet Nam
# 1652                                           Viet Nam
# 1532                                           Viet Nam
# 1386                                           Viet Nam
# 1387                                           Viet Nam
# 1388                                           Viet Nam
# 1036                                           Viet Nam
# 985                                            Viet Nam
# 925                                            Viet Nam
# 797                                            Viet Nam
# 722                                            Viet Nam
# 728                                            Viet Nam
# 686                                            Viet Nam
# 562                                            Viet Nam
# 479                                            Viet Nam
# 427                                            Viet Nam
# 255                                            Viet Nam
# 237                                            Viet Nam
# 1223                                     Western Sahara
# 242                                               Yemen
# 204                                               Yemen
# 405                                                 NaN
#
#                                            Country code  \
# 2657                                                AFG
# 1803                                                AFG
# 1648                                                AFG
# 1649                                                AFG
# 1166                                                AFG
# 1210                                                AFG
# 947                                                 AFG
# 984                                                 AFG
# 990                                                 AFG
# 1007                                                AFG
# 1009                                                AFG
# 667                                                 AFG
# 2600  ALB, DZA, BIH, BGR, HRV, GRC, MKD, MAR, ROU, T...
# 60                              ALB, BGR, GRC, MKD, SRB
# 21                              ALB, BGR, MKD, ROU, SRB
# 5     ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, F...
# 2692                                                DZA
# 2700                                                DZA
# 999                                                 DZA
# 721                                                 DZA
# 450                                                 DZA
# 451                                                 DZA
# 399                                                 DZA
# 332                                                 DZA
# 250                                                 DZA
# 203                                                 DZA
# 158                                                 DZA
# 144                                                 DZA
# 2385                                                ANG
# 2402                                                ANG
# ...                                                 ...
# 874                                                 VEN
# 791                                                 VEN
# 735                                                 VEN
# 739                                                 VEN
# 495                                                 VEN
# 497                                                 VEN
# 2175                                                VNM
# 2040                                                VNM
# 2048                                                VNM
# 1652                                                VNM
# 1532                                                VNM
# 1386                                                VNM
# 1387                                                VNM
# 1388                                                VNM
# 1036                                                VNM
# 985                                                 VNM
# 925                                                 VNM
# 797                                                 VNM
# 722                                                 VNM
# 728                                                 VNM
# 686                                                 VNM
# 562                                                 VNM
# 479                                                 VNM
# 427                                                 VNM
# 255                                                 VNM
# 237                                                 VNM
# 1223                                                ESH
# 242                                                 YEM
# 204                                                 YEM
# 405                                                 NaN
#
#                Endangerment  \
# 2657             Vulnerable
# 1803  Critically endangered
# 1648  Critically endangered
# 1649    Severely endangered
# 1166    Severely endangered
# 1210    Severely endangered
# 947   Definitely endangered
# 984     Severely endangered
# 990   Definitely endangered
# 1007  Definitely endangered
# 1009  Definitely endangered
# 667   Definitely endangered
# 2600    Severely endangered
# 60    Definitely endangered
# 21               Vulnerable
# 5     Definitely endangered
# 2692    Severely endangered
# 2700    Severely endangered
# 999   Critically endangered
# 721     Severely endangered
# 450     Severely endangered
# 451              Vulnerable
# 399              Vulnerable
# 332   Critically endangered
# 250   Critically endangered
# 203     Severely endangered
# 158              Vulnerable
# 144              Vulnerable
# 2385                Extinct
# 2402                Extinct
# ...                     ...
# 874              Vulnerable
# 791              Vulnerable
# 735   Definitely endangered
# 739              Vulnerable
# 495     Severely endangered
# 497              Vulnerable
# 2175  Critically endangered
# 2040  Critically endangered
# 2048    Severely endangered
# 1652             Vulnerable
# 1532  Critically endangered
# 1386  Definitely endangered
# 1387  Definitely endangered
# 1388  Definitely endangered
# 1036  Definitely endangered
# 985              Vulnerable
# 925   Definitely endangered
# 797     Severely endangered
# 722   Definitely endangered
# 728   Definitely endangered
# 686              Vulnerable
# 562   Definitely endangered
# 479              Vulnerable
# 427   Definitely endangered
# 255   Definitely endangered
# 237   Definitely endangered
# 1223  Critically endangered
# 242     Severely endangered
# 204   Definitely endangered
# 405   Definitely endangered
#
#                                         Alternate names  Speakers  Latitude  \
# 2657                                                NaN         0   34.6600
# 1803                                             Tirāhī       100   34.3139
# 1648                             Mogol; Mogholi; Mogoli       200   34.3569
# 1649                      Nangalami; Grangali (dialect)       200   35.2355
# 1166                          tregâmi, Tregami, Trigami      1000   34.9017
# 1210                                            Śumāśtī      1000   34.6108
# 947       âSkuNu vîri, Ashkund, Ashkuni, Wamayi, Wamais      2000   34.9973
# 984                          Munjani, Munjhan, Munjiwar      2000   36.0379
# 990      Prasun, Veruni, Parun, Wasi-Veri, Veron, Verou      2000   35.3543
# 1007  kalaSa alâ, Waigeli, Waigalii, Waigala, Zhonji...      2000   35.1895
# 1009                                                NaN      2000   34.4166
# 667                                                 NaN      6000   34.4658
# 2600  Ladino; Judeo-Spanish; Sephardic; Haketía (loc...         0   41.2607
# 60                     Macedo-Romanian; Vlach; Tsintsar    500000   40.2292
# 21             Shop; dialects: Goran, Janjev, Krashovan   1500000   42.9644
# 5                                    sinti, vlax,  calò   3500000   46.3165
# 2692  Tamazight, Berbere du Beni Snous, Ayt Snous, C...         0   34.6230
# 2700  Righia, Chelha, Shelha\nGeneric term of Tamazight         0   33.0777
# 999                                                 NaN      2000   35.5869
# 721                                        Kwarandzie\n      5000   29.4049
# 450                       Tamazight, Berbere de Ouargla     15000   30.9587
# 451            Gouraya, taqbaylit\nTamazight n Iyurayen     15000   36.5648
# 399   Tachenuit, Chenoui, Chenoua, Haqbaylit, Taqbaylit     20000   36.5703
# 332   Tidikelt is the name of the region. Now referr...     30000   26.8828
# 250                                Tamazight, taqbaylit     50000   35.5702
# 203            Tamazight du Gourara, Tamazight du Touat     80000   29.3413
# 158        Tahaggart, Tamachek, Touareg, Tuareg, Toureg    120000   22.8369
# 144                          Tumzabt, Tamzabt, Mozabite    150000   32.4816
# 2385                                                NaN         0  -17.1617
# 2402                                                NaN         0  -15.2523
# ...                                                 ...       ...       ...
# 874   Yuco. Yuko. Motilones (not to be confused with...      3000    9.7956
# 791                                  Guaharibo. Guaica.      4000    2.5918
# 735                                              Yaruro      5000    6.7518
# 739                              De'cuana. Maquiritare.      5000    4.8501
# 495                                    Galibi in Brazil     11000    8.4941
# 497                                 Uwotjüja. De'aruwa.     11000    4.5435
# 2175                                                NaN         5   19.4162
# 2040                         A-ou, A-uo, Voa De, Van To        20   23.1666
# 2048                                      Duoluo, Tu Du        20   23.2000
# 1652                                               Ainh       200   23.1500
# 1532                                       Hagei, Ho Ki       300   23.1333
# 1386                                                NaN       500   23.6166
# 1387                                                NaN       500   22.0333
# 1388                                                NaN       500   21.4666
# 1036                                                NaN      1676   22.5943
# 985                                                 NaN      2000   17.5333
# 925                                                 NaN      2300   22.3500
# 797                                                 NaN      3921   22.0333
# 722                                                 NaN      5000   22.5000
# 728                                                 NaN      5000   22.7833
# 686                                     Pa Hng, Pa Then      5569   22.8166
# 562                                                 NaN      9046   22.7833
# 479                                                 NaN     12000   11.4666
# 427                                                 NaN     15000   10.5634
# 255                                       Kucong, Lahlu     47000   22.6166
# 237                                                 NaN     50000   10.7833
# 1223  Tamazight\nCurrent usage refers to Zenaga as T...      1000   22.2687
# 242                     sk'ot'ri, sk'ot'riyyet, suqutri     50000   12.5331
# 204                        Samrit Razih, Razihit, رازحي     75000   16.8834
# 405                                            Shinasha     19878   10.3581
#
#       Longitude  Endangerment_enc
# 2657    70.2000                 0
# 1803    70.3729                 3
# 1648    61.5875                 3
# 1649    71.5100                 2
# 1166    70.9085                 2
# 1210    70.7569                 2
# 947     71.0746                 1
# 984     70.6723                 2
# 990     71.2600                 1
# 1007    71.1941                 1
# 1009    70.3333                 1
# 667     68.6370                 1
# 2600    28.4985                 2
# 60      21.1376                 1
# 21      22.1374                 0
# 5       22.3681                 1
# 2692    -1.5614                 2
# 2700     6.0671                 2
# 999     -0.4737                 3
# 721     -3.2605                 2
# 450      4.0209                 2
# 451      1.9061                 0
# 399      2.2892                 0
# 332      2.5488                 3
# 250      1.8099                 3
# 203      0.3955                 2
# 158      5.5371                 0
# 144      3.6694                 0
# 2385    16.1059                 4
# 2402    12.2277                 4
# ...         ...               ...
# 874    -72.9382                 0
# 791    -64.7314                 0
# 735    -68.2470                 1
# 739    -64.5117                 0
# 495    -64.0942                 2
# 497    -66.7089                 0
# 2175   104.4870                 3
# 2040   105.2500                 3
# 2048   105.3333                 2
# 1652   105.2166                 0
# 1532   105.2500                 3
# 1386   105.6833                 1
# 1387   103.7500                 1
# 1388   103.7500                 1
# 1036   102.7455                 1
# 985    105.3833                 0
# 925    102.9666                 1
# 797    102.6666                 2
# 722    104.1333                 1
# 728    105.3666                 1
# 686    106.3500                 0
# 562    105.4666                 1
# 479    109.0500                 0
# 427    107.1496                 1
# 255    102.7500                 1
# 237    108.0833                 1
# 1223   -13.7109                 3
# 242     53.7670                 2
# 204     43.2655                 1
# 405     35.0024                 1
#
# [2722 rows x 10 columns]

# %%
#df['Country_code'].str.split(',', expand=True)

# %%
df
# Out:
#         ID                                    Language  \
# 0     1022                               South Italian
# 1     1023                                    Sicilian
# 2      383                                   Low Saxon
# 3      335                                  Belarusian
# 4      382                                     Lombard
# 5      405                                      Romani
# 6     2211                            Yiddish (Israel)
# 7     1586                                       Gondi
# 8     1020                        Limburgian-Ripuarian
# 9     1943                 Quechua of Southern Bolivia
# 10    1565                                     Kumaoni
# 11     755                                      Aymara
# 12     349                            Emilian-Romagnol
# 13     399                                 Piedmontese
# 14    1021                                     Venetan
# 15    1985                                      Zazaki
# 16    1591                               Kurux (India)
# 17    2065                                     Tamajeq
# 18    1585                                        Tulu
# 19    1556                                      Kangdi
# 20     410                                       Scots
# 21    1026                                      Torlak
# 22    1476                                West Flemish
# 23     334                                     Bashkir
# 24    1067                                     Chechen
# 25     338                                     Chuvash
# 26    1227                                     Meithei
# 27    1114                                      Tamang
# 28    1013                            Quechua of Cuzco
# 29    1024                              Eastern Slovak
# ...    ...                                         ...
# 2692     3                                    Tasnusit
# 2693  1059                                         Tat
# 2694  1495                                        Tati
# 2695  2012                                      Tatuyo
# 2696   457                                        Tazy
# 2697  2458                                     Tempuan
# 2698  2188                                 Toba-Maskoy
# 2699   447                                      Tolcha
# 2700  2182                         Touggourt Tamazight
# 2701  2009                           Tucano (Colombia)
# 2702  2453              Tunisian Judeo-Arabic (Israel)
# 2703  2391                          Tuscarora (Canada)
# 2704  2013                           Tuyuca (Colombia)
# 2705  2192                               Udi (Georgia)
# 2706   280                                       Unami
# 2707  2392                       Upper Tanana (Canada)
# 2708  1336                                        Urum
# 2709  2475                                          Wa
# 2710  2014                 Wanano / Kotiria (Colombia)
# 2711  2393                    Western Abenaki (Canada)
# 2712   283  Western Abenaki (United States of America)
# 2713  2093                                       Wichi
# 2714  1971                                     Yaeyama
# 2715  1365                                  Yazva Komi
# 2716   428                            Yiddish (Europe)
# 2717  1972                                    Yonaguni
# 2718  2018                                      Yucuna
# 2719  2015                           Yurutí (Colombia)
# 2720  2716                                   Zangskari
# 2721  2177                                     Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# 7                                                 India
# 8                         Germany, Belgium, Netherlands
# 9                      Bolivia (Plurinational State of)
# 10                                         India, Nepal
# 11        Bolivia (Plurinational State of), Chile, Peru
# 12                                    Italy, San Marino
# 13                                                Italy
# 14                             Croatia, Italy, Slovenia
# 15                                               Turkey
# 16                                                India
# 17                                                Niger
# 18                                                India
# 19                                                India
# 20    United Kingdom of Great Britain and Northern I...
# 21    Albania, Bulgaria, The former Yugoslav Republi...
# 22                         Belgium, France, Netherlands
# 23                                   Russian Federation
# 24                                   Russian Federation
# 25                                   Russian Federation
# 26                                                India
# 27                                         India, Nepal
# 28                                                 Peru
# 29                                    Slovakia, Ukraine
# ...                                                 ...
# 2692                                            Algeria
# 2693                                         Azerbaijan
# 2694                         Iran (Islamic Republic of)
# 2695                                           Colombia
# 2696                                 Russian Federation
# 2697                                           Cambodia
# 2698                                           Paraguay
# 2699                                              India
# 2700                                            Algeria
# 2701                                           Colombia
# 2702                                             Israel
# 2703                                             Canada
# 2704                                           Colombia
# 2705                                            Georgia
# 2706                           United States of America
# 2707                                             Canada
# 2708               Georgia, Russian Federation, Ukraine
# 2709                                            Myanmar
# 2710                                           Colombia
# 2711                                             Canada
# 2712                           United States of America
# 2713        Argentina, Bolivia (Plurinational State of)
# 2714                                              Japan
# 2715                                 Russian Federation
# 2716  Germany, Austria, Belarus, Belgium, Denmark, E...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# 2720                                    India, Pakistan
# 2721                                               Oman
#
#                                            Country code  \
# 0                                                   ITA
# 1                                                   ITA
# 2                               DEU, DNK, NLD, POL, RUS
# 3                          BRB, LVA, LTU, POL, RUS, UKR
# 4                                              ITA, CHE
# 5     ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, F...
# 6                                                   ISR
# 7                                                   IND
# 8                                         DEU, BEL, NLD
# 9                                                   BOL
# 10                                             IND, NPL
# 11                                        BOL, CHL, PER
# 12                                             ITA, SMR
# 13                                                  ITA
# 14                                        HRV, ITA, SVN
# 15                                                  TUR
# 16                                                  IND
# 17                                                  NER
# 18                                                  IND
# 19                                                  IND
# 20                                                  GBR
# 21                              ALB, BGR, MKD, ROU, SRB
# 22                                        BEL, FRA, NLD
# 23                                                  RUS
# 24                                                  RUS
# 25                                                  RUS
# 26                                                  IND
# 27                                             IND, NPL
# 28                                                  PER
# 29                                             SVK, UKR
# ...                                                 ...
# 2692                                                DZA
# 2693                                                AZE
# 2694                                                IRN
# 2695                                                COL
# 2696                                                RUS
# 2697                                                KHM
# 2698                                                PRY
# 2699                                                IND
# 2700                                                DZA
# 2701                                                COL
# 2702                                                ISR
# 2703                                                CAN
# 2704                                                COL
# 2705                                                GEO
# 2706                                                USA
# 2707                                                CAN
# 2708                                      GEO, RUS, UKR
# 2709                                                MMR
# 2710                                                COL
# 2711                                                CAN
# 2712                                                USA
# 2713                                           ARG, BOL
# 2714                                                JPN
# 2715                                                RUS
# 2716  DEU, AUT, BRB, BEL, DNK, EST, FIN, FRA, HUN, I...
# 2717                                                JPN
# 2718                                                COL
# 2719                                                COL
# 2720                                           IND, PAK
# 2721                                                OMN
#
#                Endangerment  \
# 0                Vulnerable
# 1                Vulnerable
# 2                Vulnerable
# 3                Vulnerable
# 4     Definitely endangered
# 5     Definitely endangered
# 6     Definitely endangered
# 7                Vulnerable
# 8                Vulnerable
# 9                Vulnerable
# 10               Vulnerable
# 11               Vulnerable
# 12    Definitely endangered
# 13    Definitely endangered
# 14               Vulnerable
# 15               Vulnerable
# 16               Vulnerable
# 17               Vulnerable
# 18               Vulnerable
# 19    Definitely endangered
# 20               Vulnerable
# 21               Vulnerable
# 22               Vulnerable
# 23               Vulnerable
# 24               Vulnerable
# 25               Vulnerable
# 26               Vulnerable
# 27               Vulnerable
# 28               Vulnerable
# 29               Vulnerable
# ...                     ...
# 2692    Severely endangered
# 2693    Severely endangered
# 2694  Definitely endangered
# 2695  Definitely endangered
# 2696    Severely endangered
# 2697    Severely endangered
# 2698    Severely endangered
# 2699                Extinct
# 2700    Severely endangered
# 2701             Vulnerable
# 2702    Severely endangered
# 2703  Critically endangered
# 2704  Definitely endangered
# 2705    Severely endangered
# 2706                Extinct
# 2707  Critically endangered
# 2708  Definitely endangered
# 2709    Severely endangered
# 2710  Definitely endangered
# 2711  Critically endangered
# 2712                Extinct
# 2713             Vulnerable
# 2714    Severely endangered
# 2715    Severely endangered
# 2716  Definitely endangered
# 2717    Severely endangered
# 2718  Definitely endangered
# 2719  Definitely endangered
# 2720  Definitely endangered
# 2721  Critically endangered
#
#                                         Alternate names  Speakers  Latitude  \
# 0     Neapolitan; Neapolitan-Calabrese; неаполитанск...   7500000   40.9798
# 1                                                   NaN   5000000   37.4399
# 2     Low German, Niedersächsisch, Nedersaksisch, Ni...   4800000   53.4029
# 3                                                   NaN   4000000   53.9560
# 4                                                   NaN   3500000   45.7215
# 5                                    sinti, vlax,  calò   3500000   46.3165
# 6                                          Judeo-German   3000000   32.0833
# 7     Gondi; Gaudi; Gondiva; Gondwadi; Goondile; Gou...   2713790   19.5804
# 8                Colognian (dialect; in German: Kölsch)   2600000   50.7781
# 9                                                   NaN   2300000  -18.0675
# 10           Kumauni; Kamaoni; Kumau; Kumawani; Kumgoni   2003783   29.4778
# 11                   Aimara, Jaqi Aru, Southern Aymara.   2000000  -16.5835
# 12                                                  NaN   2000000   44.1270
# 13                                                  NaN   2000000   45.2013
# 14                                                  NaN   2000000   45.4601
# 15                               Zaza; Dimli; Kirmanjki   2000000   38.8824
# 16                                        Kurukh; Oraon   1751489   22.1467
# 17                                                  NaN   1750000   17.2352
# 18       Tuluva Bhasa; Tullu; Thulu; Tal; Tilu; Thalu\n   1722768   12.0178
# 19    Dogaryali; Dogri Pahari;  Tokkaru; Dogri-Kangr...   1700000   32.4356
# 20        Lallans; Northumbrian (local name in England)   1500000   56.2189
# 21             Shop; dialects: Goran, Janjev, Krashovan   1500000   42.9644
# 22                  Western Flemish; Zeelandic (Zeêuws)   1500000   51.0275
# 23                                             Bashkort   1379727   54.7309
# 24                                                  NaN   1331844   43.1971
# 25                                                  NaN   1325382   56.1394
# 26                                     Manipuri, Meitei   1250000   24.7667
# 27                     तामाङ; तामाङ्ग; Murmi (obsolete)   1196639   27.7365
# 28                                 Quechua Cuzco-Collao   1115000  -13.4537
# 29                                                  NaN   1000000   48.8068
# ...                                                 ...       ...       ...
# 2692  Tamazight, Berbere du Beni Snous, Ayt Snous, C...         0   34.6230
# 2693                                                NaN         0   41.3438
# 2694                      Tātī; Azari; Āẕarī; Takestani         0   38.2036
# 2695                                                NaN         0    0.4174
# 2696                                                Taz         0   43.9236
# 2697                                                NaN         0   13.7238
# 2698                                                NaN         0  -21.5578
# 2699                                                NaN         0   29.9333
# 2700  Righia, Chelha, Shelha\nGeneric term of Tamazight         0   33.0777
# 2701                                             Tukáno         0    0.6921
# 2702                        l'arabe des juifs tunisiens         0   32.0779
# 2703                                                NaN         0   43.0720
# 2704                                             Tuyúka         0    0.3515
# 2705                                                NaN         0   41.8905
# 2706                Delaware, Oklahoma Delaware, Lenape         0   39.1300
# 2707                                                NaN         0   62.3824
# 2708                                        Greek Tatar         0   47.0102
# 2709                                                NaN         0   21.8705
# 2710     Guanano, Kotiria is autodenomination in Brazil         0    1.0106
# 2711                                                NaN         0   46.0785
# 2712                                                NaN         0   43.0046
# 2713  Wichi, Weenhayek, Wichí Lhamtés Nocten , Wichí...         0  -22.0041
# 2714                                                NaN         0   24.3420
# 2715                                    Eastern Permyak         0   60.0348
# 2716                                       Judeo-German         0   53.3571
# 2717                                                NaN         0   24.4580
# 2718                                                NaN         0   -1.2633
# 2719                                                NaN         0    1.1370
# 2720                               Zangs-dkar, Z’angkar         0   34.0833
# 2721                                   Zidjali, Zadjali         0   23.4027
#
#       Longitude  Endangerment_enc
# 0       15.2490                 0
# 1       14.5019                 0
# 2       10.3601                 0
# 3       27.5756                 0
# 4        9.3273                 1
# 5       22.3681                 1
# 6       34.8333                 1
# 7       80.4418                 0
# 8        6.0864                 0
# 9      -65.7641                 0
# 10      79.8486                 0
# 11     -68.3020                 0
# 12      12.0739                 1
# 13       7.8662                 1
# 14      12.1948                 0
# 15      40.4846                 0
# 16      85.2758                 0
# 17       8.0859                 0
# 18      75.7067                 0
# 19      76.1242                 1
# 20      -3.7683                 0
# 21      22.1374                 0
# 22       3.0541                 0
# 23      55.9863                 0
# 24      45.7031                 0
# 25      47.2412                 0
# 26      93.8946                 0
# 27      85.6858                 0
# 28     -72.0098                 0
# 29      21.7968                 0
# ...         ...               ...
# 2692    -1.5614                 2
# 2693    48.6254                 2
# 2694    48.2519                 1
# 2695   -70.4882                 1
# 2696   134.7967                 2
# 2697   107.2038                 2
# 2698   -58.0064                 2
# 2699    80.0326                 4
# 2700     6.0671                 2
# 2701   -69.8291                 0
# 2702    34.8019                 2
# 2703   -80.0150                 3
# 2704   -70.2026                 1
# 2705    45.9130                 2
# 2706   -76.0253                 4
# 2707  -140.8984                 3
# 2708    36.7822                 1
# 2709    99.6519                 2
# 2710   -69.6423                 1
# 2711   -72.8141                 3
# 2712   -72.2460                 4
# 2713   -63.4130                 0
# 2714   124.1537                 2
# 2715    57.5360                 2
# 2716    25.2465                 1
# 2717   122.9802                 2
# 2718   -70.6640                 1
# 2719   -70.2136                 1
# 2720    76.8500                 1
# 2721    58.0957                 3
#
# [2722 rows x 10 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
#menStd = (2, 3, 4, 1, 2)
#womenStd = (3, 5, 2, 3, 3)

anything = (100,231,132,321,401)
ind = np.arange(N)    # the x locations for the groups
print(ind, menMeans)
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans) #bottom of the other one starting after the "bottom =" ends 
p3 = plt.bar(ind, anything, width, bottom=sum_menWomen)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
#plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0], p3[0]), ('Men', 'Women', 'anything'))

plt.show()
# Out:
# [0 1 2 3 4] (20, 35, 30, 35, 27)

# %%
#cerating stacked bar chart for the average number of speakers in each level of endangerment in USA


df_USA = df[df['Country code'] == "USA"][['Speakers', 'Endangerment_enc']].groupby('Endangerment_enc').count()
df_India = df[df['Country code'] == 'IND'][['Speakers', 'Endangerment_enc']].groupby('Endangerment_enc').count()
#df_mex = df[df['Country code']=='MEX'][['Speakers', 'Endangerment_enc']].groupby('Endangerment_enc').count()
df_canada = df[df['Country code']=='CAN'][['Speakers', 'Endangerment_enc']].groupby('Endangerment_enc').count()
#len(df_USA)
#print(len(df_India))
#len(df_mex)

df_canada#.Speakers#making a list of df object
# Out:
#                   Speakers
# Endangerment_enc
# 0                       24
# 1                       16
# 2                       12
# 3                       28
# 4                        2

# %%
df_USA
# Out:
#                   Speakers
# Endangerment_enc
# 0                       14
# 1                       28
# 2                       40
# 3                       80
# 4                       54

# %%
print(df_USA.index)
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64', name='Endangerment_enc')

# %%
label_to_enc
enc_to_label
# Out:
# {0: 'Vulnerable',
#  1: 'Definitely endangered',
#  2: 'Severely endangered',
#  3: 'Critically endangered',
#  4: 'Extinct'}

# %%
plt.bar(range(len(df_USA)),df_USA.Speakers.values)
plt.bar(range(len(df_India)), df_India.Speakers.values, bottom=df_USA.Speakers)
plt.bar(range(len(df_canada)), df_canada.Speakers.values, bottom=df_USA.Speakers+df_India.Speakers)

plt.ylabel('Speakers in thousands')
plt.title('Speakers of different endangerment level in three countries')
plt.xticks(df_USA.index, labels, rotation=90)
#plt.xticks('G1', 'G2', 'G3', 'G4', 'G5')
#plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0], p3[0]), ('USA', 'India', 'Canada'))

plt.show()

# %%
type(df_USA.Speakers)
type()
# Out:
# pandas.core.series.Series

# %%
list(df_USA)
type(df_USA.Speakers)
# Out:
# pandas.core.series.Series

# %%
[df_USA.Speakers + df_India.Speakers]
# Out:
# [Endangerment_enc
#  0     80
#  1     73
#  2     46
#  3    120
#  4     60
#  Name: Speakers, dtype: int64]

# %%
type(menMeans)
# Out:
# tuple

# %%
menMeansLst = list(menMeans)
womenLst = list(womenMeans)

# %%
type(menMeansLst)
# Out:
# list

# %%
menMeansLst + womenLst
# Out:
# [20, 35, 30, 35, 27, 25, 32, 34, 20, 25]

# %%
sum_menWomen = np.array(menMeans) + np.array(womenMeans)
print(sum_menWomen)
# Out:
# [45 67 64 55 52]

# %%
df3= df[['Speakers', 'Endangerment']]
df3
df4=pd.pivot_table(df3,index=["Endangerment"], value=[df3.Speakers.mean()])
df4.plot.bar(stacked=True)

#df3.plot.bar(stacked=True)
#pd.crosstab(df3.Speakers, df.Endangerment).plot.barh(stacked=True)
#df3.pivot(df3.Endangerment_enc, df3.Population.sum()).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-e69132a17a59> in <module>()
#       1 df3= df[['Speakers', 'Endangerment']]
#       2 df3
# ----> 3 df4=pd.pivot_table(df3,index=["Endangerment"], value=[df3.Speakers.mean()])
#       4 df4.plot.bar(stacked=True)
#       5
#
# TypeError: pivot_table() got an unexpected keyword argument 'value'

# %%
df4 = pd.DataFrame({"session":[1,1,2,2,3,3],
              "query":list("ababab"), "count":[5,7,32,5,8,1]})
print(df4)
df4.pivot("session","query").plot(kind="bar", stacked=True)
# Out:
#    count query  session
# 0      5     a        1
# 1      7     b        1
# 2     32     a        2
# 3      5     b        2
# 4      8     a        3
# 5      1     b        3

# %%
index = np.arange(len(labels))
bar_width = 0.35
language = []
speaker = []
for i in range(len(labels)):
    language.append(len(df[df.Endangerment==i]))
    speaker.append(np.mean(df[df.Endangerment==i].Speakers)/100)
plt.figure()
plt.bar(index, language, bar_width, align='center', 
        label='Total languages', color='blue')
plt.bar(index+bar_width, speaker, bar_width, align='center', 
        label='Mean Speakers(in 100s)', color='red')
plt.xticks(index, labels, rotation=45)
plt.tight_layout()
plt.title('Degree of Endangerment')
plt.legend(loc=1)

# %%
countries_list = ['Nepal', 'China', 'Brazil', 'Russia', 
                  'Indonesia', 'United States of America']
colors = ["lightgreen", "yellow", "orange", "red", "maroon"]
countries = [0]*len(countries_list)

#Number of extinct speakers is zero for most of the countries
danger_countries = [countries]*(len(labels)-1) 
#print(danger_countries)

index = np.arange(len(countries_list))
#print(index)
for danger in range(len(labels)-1):
    print(danger, labels[danger])
    for country in range(len(countries_list)):
        print(danger_countries[danger][country])
        danger_countries[danger][country] = sum(df[(df.Countries.str.contains(countries_list[country])==True) 
                 & (df.Endangerment==danger)].Speakers.astype(int))
        
#Plotting the graph
plt.figure()
plt.bar(index, danger_countries[0], bar_width, label=enc_to_label[0], 
        align='center', color=colors[0])
#
for i in range(1, len(danger_countries)):
    bottom = [sum(k) for k in zip(*danger_countries[0:i][:])] 
    plt.bar(index, danger_countries[i], bar_width, label=enc_to_label[i], 
            align='center', color=colors[i], bottom=bottom)
#
plt.xticks(index, countries_list, rotation=20)
plt.xlabel('Countries')
plt.ylabel('Number of speakers')
plt.legend(bbox_to_anchor=(1.1, 1.1))
plt.tight_layout()
# Out:
# 0 Vulnerable
# 0
# 0
# 0
# 0
# 0
# 0
# 1 Definitely endangered
# 0
# 0
# 0
# 0
# 0
# 0
# 2 Severely endangered
# 0
# 0
# 0
# 0
# 0
# 0
# 3 Critically endangered
# 0
# 0
# 0
# 0
# 0
# 0

# %%
df.Speakers.iloc[0].type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-83732aa4d6bc> in <module>()
# ----> 1 df.Speakers.iloc[0].type
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Speakers'

# %%
df[df['Speakers'] > 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Speakers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-d3bd357fa907> in <module>()
# ----> 1 df[df['Speakers'] > 0]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Speakers'

# %%
#First visualization- what is the distribution of speakers in endangered languages


#plotting a histogram to see the distribution of the number of speakers in these endangered langauges 
fig = plt.figure(figsize=(16,8))

plt.hist(df[df['Speakers'] >0 ]['Speakers'], bins=[0,1,1000,2000,3000])
#plt.hist(df[df['Speakers'] > 0], bins=500)
#plt.xlim(1,200000)
plt.xlabel('Number of speakers')
plt.ylabel('Number of languages')
plt.show

#This plot shows that a large number of endangered langauges have very low number of speakers
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Speakers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-48690467ba68> in <module>()
#       5 fig = plt.figure(figsize=(16,8))
#       6
# ----> 7 plt.hist(df[df['Speakers'] >0 ]['Speakers'], bins=[0,1,1000,2000,3000])
#       8 #plt.hist(df[df['Speakers'] > 0], bins=500)
#       9 #plt.xlim(1,200000)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Speakers'

# %%
.5/.75
# Out:
# 0.6666666666666666

# %%
df1=df.groupby(df['Endangerment'])['Speakers'].count()
df1
df2=df.groupby(df['Country code'])['Endangerment']
df2.plot.bar(stacked=True)


#df1.plot.bar(stacked=True)#, bins=[0,1,1000,2000,3000])
#.unstack('Abuse/NFF').fillna(0)
#df2[['abuse','nff']].plot(kind='bar', stacked=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-c12b42064cb3> in <module>()
# ----> 1 df1=df.groupby(df['Endangerment'])['Speakers'].count()
#       2 df1
#       3 df2=df.groupby(df['Country code'])['Endangerment']
#       4 df2.plot.bar(stacked=True)
#       5
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     257         else:
#     258             if key not in self.obj:
# --> 259                 raise KeyError("Column not found: {key}".format(key=key))
#     260             return self._gotitem(key, ndim=1)
#     261
#
# KeyError: 'Column not found: Speakers'

# %%
#Question: Which endangerment level has the most number of languages?

df['Endangerment'].value_counts().plot(kind='bar')
plt.ylabel('Language count')
plt.xlabel('Types of endangered languages')
plt.title('Language count for language endangerment levels')
# Out:
# Text(0.5,1,'Language count for language endangerment levels')

# %%
#Mean speaker count for endangered languages 

df[df.Endangerment].Speakers.value_counts().mean().plot(kind='bar')

#plt.ylabel('Language count')
#plt.xlabel('Types of endangered languages')
#plt.title('Language count for language endangerment levels')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-004467acf448> in <module>()
#       1 #Mean speaker count for endangered languages
#       2
# ----> 3 df[df.Endangerment].Speakers.value_counts().mean().plot(kind='bar')
#       4
#       5 #plt.ylabel('Language count')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['Vulnerable' 'Vulnerable' 'Vulnerable' ... 'Definitely endangered'\n 'Definitely endangered' 'Critically endangered'] not in index"

# %%
#Q: What is the endangered language situation in the United States? 

df[df.Countries == 'United States of America'].Endangerment.value_counts().plot(kind='bar')

plt.ylabel('Language count?')
plt.xlabel('Types of endangered languages in the United States')
plt.title('Language endangerment levels in the United States')
plt.show()
##Question: how to sort by a given order 

#Stack overflow example
#order = ['Mon', 'Tues', 'Weds','Thurs','Fri','Sat','Sun']
#df.pivot('day','group','amount').loc[order].plot(kind='bar')
order = ['Vulnerable', 'Definitely endangered', 'Severely endangered',
       'Critically endangered', 'Extinct']
#df.Endangerment('Vulnerable').loc[order].plot(kind='bar')

plt.show()

# %%
#Another way
language_spoken_USA = df[df['Country code'].str.contains('USA') == True]
len(language_spoken_USA)

df[df['Country code'].str.contains('USA')].Endangerment.value_counts().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country code'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-fa6d5663d899> in <module>()
#       1 #Another way
# ----> 2 language_spoken_USA = df[df['Country code'].str.contains('USA') == True]
#       3 len(language_spoken_USA)
#       4
#       5 df[df['Country code'].str.contains('USA')].Endangerment.value_counts().plot(kind='bar')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country code'

# %%
#Same distribution in India 

df[df.Countries == 'India'].Endangerment.value_counts().plot(kind='bar')

plt.ylabel('Language count?')
plt.xlabel('Types of endangered languages in India')
plt.title('Language endangerment levels in India')
# Out:
# Text(0.5,1,'Language endangerment levels in India')

# %%
#Q: which countries have the most number of endangered languages? 

df.columns
# Out:
# Index(['ID', 'Language', 'Countries', 'Country_code', 'Endangerment',
#        'Alternate names', 'Population', 'Latitude', 'Longitude',
#        'Endangerment_enc'],
#       dtype='object')

# %%
number_of_speakers = df[['Language', 'Speakers']].sort_values('Speakers', ascending=True)
print(number_of_speakers)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-a7320db5dba1> in <module>()
# ----> 1 number_of_speakers = df[['Language', 'Speakers']].sort_values('Speakers', ascending=True)
#       2 print(number_of_speakers)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['Speakers'] not in index"

# %%
#creating a pie plot for languages in the USA

#language_spoken_USA.plot.pie(figsize=(6,6), subplots=True, ignore=True)

# %%
df[df.Countries == 'India'].Endangerment.value_counts().plot(kind='bar')

# %%
len(df.Name) # there are 1090 languages
print(df.Countries.unique)
plt.pie(df.Countries.count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-c1b234087c5a> in <module>()
#       1
# ----> 2 len(df.Name) # there are 1090 languages
#       3 print(df.Countries.unique)
#       4 plt.pie(df.Countries.count())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Name'

# %%
##process data to create counts by country 

#split the place on commas
locations = df.Countries.str.split(',',1).tolist() #returns a list
locations=[x for x in locations if str(x) != 'nan']
countries = []
locations
# Out:
# [['Italy'],
#  ['Italy'],
#  ['Germany', ' Denmark, Netherlands, Poland, Russian Federation'],
#  ['Belarus', ' Latvia, Lithuania, Poland, Russian Federation, Ukraine'],
#  ['Italy', ' Switzerland'],
#  ['Albania',
#   ' Germany, Austria, Belarus, Bosnia and Herzegovina, Bulgaria, Croatia, Estonia, Finland, France, Greece, Hungary, Italy, Latvia, Lithuania, The former Yugoslav Republic of Macedonia, Netherlands, Poland, Romania, United Kingdom of Great Britain and Northern Ireland, Russian Federation, Slovakia, Slovenia, Switzerland, Czech Republic, Turkey, Ukraine, Serbia, Montenegro'],
#  ['Israel'],
#  ['India'],
#  ['Germany', ' Belgium, Netherlands'],
#  ['Bolivia (Plurinational State of)'],
#  ['India', ' Nepal'],
#  ['Bolivia (Plurinational State of)', ' Chile, Peru'],
#  ['Italy', ' San Marino'],
#  ['Italy'],
#  ['Croatia', ' Italy, Slovenia'],
#  ['Turkey'],
#  ['India'],
#  ['Niger'],
#  ['India'],
#  ['India'],
#  ['United Kingdom of Great Britain and Northern Ireland'],
#  ['Albania',
#   ' Bulgaria, The former Yugoslav Republic of Macedonia, Romania, Serbia'],
#  ['Belgium', ' France, Netherlands'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['India'],
#  ['India', ' Nepal'],
#  ['Peru'],
#  ['Slovakia', ' Ukraine'],
#  ['France', ' Italy, Monaco'],
#  ['Hungary', ' Poland, Romania, Slovakia, Ukraine'],
#  ['Azerbaijan', ' Iran (Islamic Republic of)'],
#  ['India'],
#  ['India'],
#  ['India'],
#  ['Italy'],
#  ['Guatemala'],
#  ['Peru'],
#  ['Nepal'],
#  ['Myanmar', ' Thailand'],
#  ['Belarus', ' Poland, Ukraine'],
#  ['Mali'],
#  ['Russian Federation'],
#  ['India'],
#  ['United Kingdom of Great Britain and Northern Ireland'],
#  ['India', ' Nepal'],
#  ['Guatemala'],
#  ['Belgium', ' France'],
#  ['Bangladesh', ' India'],
#  ['Spain', ' France'],
#  ['Russian Federation', ' Turkey'],
#  ['India'],
#  ['Italy'],
#  ['Peru'],
#  ['Belgium', ' France, Luxembourg'],
#  ['India'],
#  ['Georgia', ' Russian Federation'],
#  ['India'],
#  ['Russian Federation'],
#  ['Albania',
#   ' Bulgaria, Greece, The former Yugoslav Republic of Macedonia, Serbia'],
#  ['Iran (Islamic Republic of)', ' Pakistan, Afghanistan'],
#  ['France'],
#  ['Azerbaijan', ' Russian Federation'],
#  ['India'],
#  ['Nepal'],
#  ['Guatemala'],
#  ['Russian Federation'],
#  ['Mexico'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Guatemala'],
#  ['India'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['India'],
#  ['Israel'],
#  ['China'],
#  ['France'],
#  ['Italy'],
#  ['Chile'],
#  ['Mexico'],
#  ['Germany', ' Belgium, France, Luxembourg'],
#  ['Nepal'],
#  ['China'],
#  ['Georgia'],
#  ['Netherlands'],
#  ['Nepal'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Russian Federation'],
#  ['Iraq',
#   ' Israel, Jordan, The former Yugoslav Republic of Macedonia, Russian Federation, Syrian Arab Republic, Turkey'],
#  ['Russian Federation'],
#  ['India'],
#  ['India'],
#  ['India', ' Nepal'],
#  ['Israel'],
#  ['Ukraine'],
#  ['Armenia', ' Georgia, Greece, Russian Federation, Turkey, Ukraine'],
#  ['Ecuador'],
#  ['China'],
#  ['China', ' Kyrgyzstan, Mongolia'],
#  ['India'],
#  ['Nigeria'],
#  ['France'],
#  ['Spain', ' France'],
#  ['China'],
#  ['India'],
#  ['India'],
#  ['India'],
#  ['China', ' Mongolia, Russian Federation'],
#  ['Libyan Arab Jamahiriya'],
#  ['Armenia',
#   ' Iran (Islamic Republic of), Iraq, Syrian Arab Republic, Turkey'],
#  ['India'],
#  ['Pakistan'],
#  ['Pakistan'],
#  ['Russian Federation'],
#  ['France', ' Italy'],
#  ['France'],
#  ['Nigeria'],
#  ['India'],
#  ['India'],
#  ['Iran (Islamic Republic of)'],
#  ['India'],
#  ['Russian Federation'],
#  ['Iraq', ' Lebanon, Syrian Arab Republic'],
#  ['Cambodia'],
#  ['Bhutan', ' China, India'],
#  ['India'],
#  ['Republic of Moldova', ' Ukraine'],
#  ['India'],
#  ['China', ' India'],
#  ['India'],
#  ['India'],
#  ['Panama'],
#  ['India'],
#  ['France', ' Italy'],
#  ['Bhutan'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Spain', ' Portugal'],
#  ['Latvia', ' Russian Federation'],
#  ['France'],
#  ['India'],
#  ['Algeria'],
#  ['China', ' India, Nepal'],
#  ['India'],
#  ['Guatemala'],
#  ['India'],
#  ['India'],
#  ['Georgia', ' Turkey'],
#  ['Russian Federation'],
#  ['India'],
#  ['Georgia', ' Russian Federation, Turkey'],
#  ['India'],
#  ['India'],
#  ['United States of America'],
#  ['Italy'],
#  ['Algeria'],
#  ['India'],
#  ['Mexico'],
#  ['India'],
#  ['India'],
#  ['China', ' India'],
#  ['China'],
#  ['India'],
#  ['Mexico'],
#  ['Ukraine'],
#  ['China'],
#  ['France', ' Italy, Switzerland'],
#  ['Italy'],
#  ['Argentina'],
#  ['Oman', ' Yemen'],
#  ['Nicaragua'],
#  ['China'],
#  ['Bolivia (Plurinational State of)'],
#  ['Kenya', ' United Republic of Tanzania'],
#  ['Honduras'],
#  ['Colombia'],
#  ['India'],
#  ['Tajikistan', ' Afghanistan'],
#  ['Russian Federation'],
#  ['Guatemala'],
#  ['India'],
#  ['Russian Federation'],
#  ['Sudan'],
#  ['Ecuador'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Pakistan'],
#  ['Mexico'],
#  ['India'],
#  ['India'],
#  ['Guatemala'],
#  ['Guatemala'],
#  ['Ethiopia'],
#  ['India'],
#  ['Italy'],
#  ['Iran (Islamic Republic of)'],
#  ['Colombia'],
#  ['Argentina'],
#  ['Georgia'],
#  ["Lao People's Democratic Republic", ' Viet Nam'],
#  ['Algeria'],
#  ['Yemen'],
#  ['China', ' Pakistan, Tajikistan, Afghanistan'],
#  ['Bangladesh', ' India'],
#  ['Sudan'],
#  ['New Zealand'],
#  ["Lao People's Democratic Republic"],
#  ['India', ' Pakistan'],
#  ['India'],
#  ['Italy'],
#  ['Bangladesh'],
#  ['Guatemala'],
#  ['Guam (U.S.A.)'],
#  ['Peru'],
#  ['India'],
#  ['Panama'],
#  ['India'],
#  ['India'],
#  ['India'],
#  ['Faroe Islands'],
#  ['China'],
#  ['Pakistan'],
#  ['Guatemala'],
#  ['India'],
#  ['United Kingdom of Great Britain and Northern Ireland'],
#  ['Mexico'],
#  ['Costa Rica'],
#  ['Poland'],
#  ['Russian Federation'],
#  ['India'],
#  ['Greece'],
#  ['Russian Federation'],
#  ['China', ' Mongolia'],
#  ['Bhutan', ' China, India'],
#  ['Viet Nam'],
#  ['India'],
#  ['China'],
#  ['India'],
#  ['Ecuador'],
#  ['Yemen'],
#  ['Russian Federation'],
#  ['Romania'],
#  ['Syrian Arab Republic', ' Turkey'],
#  ['Estonia', ' Russian Federation'],
#  ['Greenland (Kingdom of Denmark)'],
#  ['Turkey'],
#  ['United Republic of Tanzania'],
#  ['Algeria'],
#  ['Mexico'],
#  ['India'],
#  ['India'],
#  ['China'],
#  ['Viet Nam'],
#  ['China'],
#  ['Sudan'],
#  ['Ecuador'],
#  ['Nepal'],
#  ['Ireland', ' United Kingdom of Great Britain and Northern Ireland'],
#  ['Nigeria'],
#  ['Mexico'],
#  ['Lesotho'],
#  ['Cook Islands'],
#  ['Iran (Islamic Republic of)'],
#  ['Kazakhstan', ' Kyrgyzstan'],
#  ['India'],
#  ['Senegal'],
#  ['Nepal'],
#  ['Argentina', ' Bolivia (Plurinational State of)'],
#  ['India'],
#  ['Bhutan'],
#  ['Sudan'],
#  ['India'],
#  ['Myanmar'],
#  ['Thailand'],
#  ['Peru'],
#  ['Ecuador'],
#  ['India'],
#  ['Niger'],
#  ['Peru'],
#  ['India'],
#  ['Sudan'],
#  ["Lao People's Democratic Republic"],
#  ['Mexico'],
#  ['India'],
#  ['Russian Federation'],
#  ['Nepal'],
#  ['Mexico'],
#  ['China'],
#  ['Guatemala'],
#  ['Mexico'],
#  ['Switzerland'],
#  ['India'],
#  ['India'],
#  ['India'],
#  ['Ecuador'],
#  ['Brazil', ' Colombia, Peru'],
#  ['Peru'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Guatemala'],
#  ['India'],
#  ['India'],
#  ['Mexico'],
#  ['Nepal'],
#  ['India'],
#  ['Mexico'],
#  ['Indonesia'],
#  ['Nepal'],
#  ['India'],
#  ['Russian Federation', ' Turkey'],
#  ['India'],
#  ['China'],
#  ['Indonesia'],
#  ['Bhutan'],
#  ['Austria', ' Hungary, Slovakia'],
#  ['Iran (Islamic Republic of)'],
#  ['Israel'],
#  ['Nepal'],
#  ['Italy'],
#  ['Bhutan', ' India, Nepal'],
#  ['China'],
#  ['Myanmar', ' Thailand'],
#  ['Sudan'],
#  ['China'],
#  ['Finland', ' Norway, Russian Federation, Sweden'],
#  ['Peru'],
#  ['Ecuador'],
#  ['Tajikistan', ' Afghanistan'],
#  ['India'],
#  ['Indonesia'],
#  ['Algeria'],
#  ['Argentina'],
#  ['Russian Federation'],
#  ['Croatia', ' Serbia'],
#  ['China'],
#  ['Russian Federation'],
#  ['Azerbaijan', ' Russian Federation'],
#  ['Pakistan'],
#  ['India'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Nepal'],
#  ['India'],
#  ['Mexico'],
#  ['Mexico'],
#  ['China'],
#  ['Mexico'],
#  ['Nepal'],
#  ['Senegal'],
#  ['India'],
#  ['Romania', ' Serbia'],
#  ['Romania'],
#  ['India'],
#  ['China'],
#  ['Honduras'],
#  ['Finland', ' Russian Federation'],
#  ["Lao People's Democratic Republic", ' Thailand'],
#  ['United States of America'],
#  ['Morocco'],
#  ['Azerbaijan', ' Russian Federation'],
#  ['Guyana', ' Venezuela (Bolivarian Republic of)'],
#  ['Nepal'],
#  ['China'],
#  ['Russian Federation'],
#  ['Colombia'],
#  ['India'],
#  ['Iran (Islamic Republic of)', ' Iraq'],
#  ['India'],
#  ['India'],
#  ['Panama'],
#  ['Guinea-Bissau'],
#  ['India'],
#  ['India'],
#  ['Nigeria'],
#  ['China'],
#  ['Sudan'],
#  ['Iran (Islamic Republic of)'],
#  ['Iran (Islamic Republic of)'],
#  ['Iran (Islamic Republic of)'],
#  ['Canada'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Mexico'],
#  ['China'],
#  ['India'],
#  ['Thailand'],
#  ['Bhutan'],
#  ['Bulgaria', ' Romania'],
#  ['Nepal'],
#  ['Italy'],
#  ['Brazil'],
#  ['Finland', ' Russian Federation'],
#  ['India'],
#  ['India'],
#  ['Ukraine'],
#  ['India'],
#  ['Guyana', ' Venezuela (Bolivarian Republic of)'],
#  ['Algeria'],
#  ['China'],
#  ['Syrian Arab Republic'],
#  ['Tajikistan'],
#  ['Myanmar'],
#  ['Botswana'],
#  ['Germany'],
#  ['India'],
#  ['India'],
#  ['Brazil'],
#  ['Pakistan', ' Afghanistan'],
#  ['Nepal'],
#  ['Brazil'],
#  ['Mexico'],
#  ['Iran (Islamic Republic of)'],
#  ['Senegal'],
#  ['Senegal'],
#  ['India'],
#  ['Libyan Arab Jamahiriya'],
#  ['Canada'],
#  ['India'],
#  ['Ethiopia'],
#  ['India'],
#  ['Peru'],
#  ['Uganda'],
#  ['Russian Federation'],
#  ['China'],
#  ['Viet Nam'],
#  ['Iran (Islamic Republic of)'],
#  ['Bhutan'],
#  ['China'],
#  ['India'],
#  ['Nigeria'],
#  ['Nepal'],
#  ['China'],
#  ["Lao People's Democratic Republic"],
#  ['Ethiopia'],
#  ['China'],
#  ['Thailand'],
#  ['Brazil'],
#  ['India'],
#  ['China'],
#  ['Thailand'],
#  ['United States of America'],
#  ['United States of America'],
#  ['China'],
#  ['China'],
#  ['Malaysia'],
#  ['Sudan'],
#  ['Egypt'],
#  ['Algeria'],
#  ['Algeria'],
#  ['Indonesia'],
#  ['Colombia'],
#  ['Nepal'],
#  ['India'],
#  ['French Polynesia (France)'],
#  ['Sudan'],
#  ['Belize'],
#  ['Nepal'],
#  ['Bangladesh', ' India'],
#  ['Brazil'],
#  ['Niue'],
#  ['Indonesia'],
#  ['Senegal'],
#  ['Brazil'],
#  ['Indonesia'],
#  ['India'],
#  ['Guinea'],
#  ['Sudan'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Belize'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Guinea'],
#  ['Indonesia'],
#  ['India'],
#  ['Russian Federation'],
#  ['Viet Nam'],
#  ['India'],
#  ['China'],
#  ['China'],
#  ['China'],
#  ['Indonesia'],
#  ['Indonesia'],
#  ['Russian Federation'],
#  ['Mexico'],
#  ['Guatemala'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Ethiopia', ' Sudan'],
#  ['Ghana'],
#  ['Guatemala'],
#  ['China', ' India'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Peru'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Tuvalu'],
#  ['Colombia'],
#  ['Senegal'],
#  ['Nepal'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Papua New Guinea'],
#  ['Indonesia'],
#  ['Nepal'],
#  ['Senegal'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Italy'],
#  ['Spain'],
#  ['China'],
#  ['Uzbekistan'],
#  ['China'],
#  ['United Republic of Tanzania'],
#  ['Peru'],
#  ['United States of America'],
#  ['Sweden'],
#  ['Colombia', ' Peru'],
#  ['Israel'],
#  ['Chad'],
#  ['Russian Federation'],
#  ['Senegal'],
#  ['Azerbaijan'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Bhutan'],
#  ['India'],
#  ['China'],
#  ['Bolivia (Plurinational State of)'],
#  ['India'],
#  ['India'],
#  ['Brazil'],
#  ['Nigeria'],
#  ['Germany'],
#  ['Russian Federation'],
#  ['Thailand'],
#  ['Bhutan'],
#  ['Malaysia'],
#  ['Sudan'],
#  ['China'],
#  ['China'],
#  ['Indonesia'],
#  ['China'],
#  ['Tunisia'],
#  ['China'],
#  ['Sudan'],
#  ['Malaysia'],
#  ['Russian Federation', ' Turkmenistan'],
#  ['United Republic of Tanzania'],
#  ['Colombia'],
#  ['Senegal'],
#  ['Guatemala'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Pakistan', ' Afghanistan'],
#  ['China', ' India, Myanmar'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Canada'],
#  ['Canada'],
#  ['Viet Nam'],
#  ['Nepal'],
#  ['Indonesia'],
#  ['Indonesia'],
#  ['China', ' India'],
#  ['Nicaragua'],
#  ['United States of America'],
#  ['Belize'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Ethiopia'],
#  ['Pakistan'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Chad'],
#  ['Mexico'],
#  ['Canada'],
#  ['United States of America'],
#  ['Ethiopia'],
#  ['French Polynesia (France)'],
#  ['Sudan'],
#  ['Sudan'],
#  ['Japan'],
#  ['Colombia'],
#  ['Sudan'],
#  ['China'],
#  ['Bhutan'],
#  ['Paraguay'],
#  ['Brazil'],
#  ['United States of America'],
#  ['Ecuador'],
#  ['India'],
#  ['China'],
#  ['Malaysia'],
#  ['Sudan'],
#  ['Peru'],
#  ['China'],
#  ['Peru'],
#  ['Mexico'],
#  ['Burkina Faso'],
#  ['Guyana'],
#  ['Russian Federation'],
#  ['Costa Rica'],
#  ['Colombia'],
#  ['Israel'],
#  ['Mexico'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Brazil'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Peru'],
#  ['India'],
#  ['Iran (Islamic Republic of)'],
#  ['Kenya'],
#  ['China'],
#  ['Iran (Islamic Republic of)'],
#  ['China'],
#  ['Russian Federation'],
#  ['Iran (Islamic Republic of)'],
#  ['Iran (Islamic Republic of)'],
#  ['Uzbekistan', ' Tajikistan, Afghanistan'],
#  ['United Republic of Tanzania'],
#  ['Iran (Islamic Republic of)'],
#  ['Iran (Islamic Republic of)'],
#  ['Brazil'],
#  ['Guyana'],
#  ['Central African Republic', ' Democratic Republic of the Congo, Sudan'],
#  ['China'],
#  ['Guatemala'],
#  ['Ethiopia'],
#  ['Micronesia (Federated States of)', ' Nauru'],
#  ['Panama'],
#  ['Mexico'],
#  ['Canada'],
#  ['Canada'],
#  ['Mexico'],
#  ['China', ' India'],
#  ['United States of America'],
#  ['Mexico'],
#  ['Ethiopia'],
#  ['Sudan'],
#  ['China'],
#  ['Sudan'],
#  ['Russian Federation'],
#  ['Canada'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Ethiopia'],
#  ['Bolivia (Plurinational State of)'],
#  ['Sudan'],
#  ['Russian Federation'],
#  ['Nepal'],
#  ['Sudan'],
#  ['Brazil'],
#  ['Russian Federation'],
#  ['Mexico'],
#  ['Canada'],
#  ['Sudan'],
#  ['Indonesia'],
#  ['Brazil'],
#  ['Nigeria'],
#  ['Brazil'],
#  ['Myanmar', ' Thailand'],
#  ['Nauru'],
#  ['Brazil'],
#  ['Afghanistan'],
#  ['Peru'],
#  ['Libyan Arab Jamahiriya'],
#  ['China', ' India'],
#  ['Russian Federation'],
#  ['United States of America'],
#  ['Brazil'],
#  ['Tajikistan'],
#  ['Nepal'],
#  ['Micronesia (Federated States of)'],
#  ['Brazil', ' Colombia, Venezuela (Bolivarian Republic of)'],
#  ['Guyana', ' Venezuela (Bolivarian Republic of)'],
#  ['Russian Federation'],
#  ['Russian Federation'],
#  ['Canada'],
#  ['Guatemala'],
#  ['Costa Rica'],
#  ['Senegal'],
#  ['Senegal'],
#  ['Viet Nam'],
#  ['Mexico'],
#  ['Pakistan'],
#  ['Bangladesh'],
#  ['Pakistan'],
#  ['Mexico'],
#  ['Bolivia (Plurinational State of)'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Sudan'],
#  ["Lao People's Democratic Republic", ' Myanmar, Thailand'],
#  ['China'],
#  ['Russian Federation'],
#  ['Ethiopia'],
#  ['Colombia'],
#  ['Tajikistan'],
#  ['China', ' India'],
#  ['Bhutan'],
#  ['United States of America'],
#  ['Colombia'],
#  ['China'],
#  ['Indonesia'],
#  ['United Republic of Tanzania'],
#  ['India'],
#  ['Bolivia (Plurinational State of)'],
#  ['Sweden'],
#  ['United States of America'],
#  ['Nigeria'],
#  ['Oman'],
#  ['Pakistan'],
#  ['United Republic of Tanzania'],
#  ['China'],
#  ['Oman'],
#  ['Namibia'],
#  ['India'],
#  ['Algeria'],
#  ['Viet Nam'],
#  ['China'],
#  ['Cook Islands'],
#  ['Greece', ' The former Yugoslav Republic of Macedonia'],
#  ['India'],
#  ['China'],
#  ['Viet Nam'],
#  ['Italy'],
#  ['Morocco'],
#  ['China'],
#  ['Indonesia'],
#  ['Guyana'],
#  ['India'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['India'],
#  ['India'],
#  ['Azerbaijan'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Nepal'],
#  ['Russian Federation'],
#  ['Colombia'],
#  ['Nepal'],
#  ['Mexico'],
#  ['China'],
#  ['Canada'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Nepal'],
#  ['China'],
#  ['Canada'],
#  ['Sudan'],
#  ['Peru'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Tokelau'],
#  ['Indonesia'],
#  ['Nepal'],
#  ['Canada'],
#  ['Ethiopia'],
#  ['Sudan'],
#  ['Ghana'],
#  ['Nepal'],
#  ['Cameroon', ' Equatorial Guinea'],
#  ['Congo', ' Gabon'],
#  ['Canada'],
#  ['Canada'],
#  ['Mexico'],
#  ['United States of America'],
#  ['India', ' Sudan'],
#  ['Guinea'],
#  ['Guinea'],
#  ['Russian Federation'],
#  ['India'],
#  ['Peru'],
#  ['Ecuador'],
#  ['China'],
#  ['China'],
#  ['Russian Federation'],
#  ['Guyana', ' Suriname'],
#  ['Israel'],
#  ["Lao People's Democratic Republic"],
#  ['Indonesia'],
#  ['Indonesia'],
#  ['China', ' Nepal'],
#  ['China'],
#  ['Botswana'],
#  ['Sudan'],
#  ['Brazil'],
#  ['Peru'],
#  ['Brazil'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['China'],
#  ['Mauritania'],
#  ['India'],
#  ['India'],
#  ['Guatemala'],
#  ['Viet Nam'],
#  ['Ghana'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Nepal'],
#  ['Bolivia (Plurinational State of)'],
#  ['India'],
#  ['China'],
#  ['Ethiopia'],
#  ['Papua New Guinea'],
#  ['Sudan'],
#  ['Guatemala'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Sudan'],
#  ['Myanmar'],
#  ['Colombia'],
#  ['United States of America'],
#  ['Myanmar'],
#  ['Sudan'],
#  ['Indonesia'],
#  ['Canada'],
#  ['Nigeria'],
#  ['Sudan'],
#  ['Mexico'],
#  ['Senegal'],
#  ['Panama'],
#  ['Sudan'],
#  ['Ethiopia'],
#  ['Indonesia'],
#  ['Mexico'],
#  ['Belize'],
#  ['Mexico'],
#  ['Mexico'],
#  ['Azerbaijan', ' Russian Federation'],
#  ['Libyan Arab Jamahiriya'],
#  ['Indonesia'],
#  ['Gabon', ' Equatorial Guinea'],
#  ['Indonesia'],
#  ['Kenya'],
#  ['Congo'],
#  ['India'],
#  ['Azerbaijan'],
#  ['Eritrea'],
#  ['Greenland (Kingdom of Denmark)'],
#  ['Russian Federation'],
#  ['Nigeria'],
#  ['India'],
#  ['Nigeria'],
#  ['Oman'],
#  ['Ethiopia'],
#  ['United States of America'],
#  ['Ghana'],
#  ['Micronesia (Federated States of)'],
#  ['Papua New Guinea'],
#  ['Cameroon'],
#  ['China'],
#  ['Nepal'],
#  ['Israel'],
#  ['Russian Federation'],
#  ['Argentina', ' Uruguay'],
#  ['United States of America'],
#  ['China', ' Russian Federation'],
#  ['Indonesia'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Argentina'],
#  ['Australia'],
#  ['Guinea'],
#  ['Fiji'],
#  ['Pakistan', ' Afghanistan'],
#  ['India'],
#  ['China'],
#  ['India'],
#  ['China'],
#  ['Micronesia (Federated States of)'],
#  ['Timor-Leste'],
#  ['Australia'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['Canada'],
#  ['Brazil'],
#  ['United Kingdom of Great Britain and Northern Ireland'],
#  ['Nepal'],
#  ['Canada'],
#  ['Mexico'],
#  ['Russian Federation'],
#  ['Myanmar', ' Thailand'],
#  ['Brazil'],
#  ['China'],
#  ['China'],
#  ['Sudan'],
#  ['Bolivia (Plurinational State of)'],
#  ['India'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Angola'],
#  ['Sudan'],
#  ["Lao People's Democratic Republic", ' Viet Nam'],
#  ['Mexico'],
#  ['Brazil'],
#  ['Panama'],
#  ['Ecuador', ' Peru'],
#  ['Sudan'],
#  ['Mali'],
#  ['Peru'],
#  ['Chad'],
#  ['Azerbaijan'],
#  ['China'],
#  ['Myanmar'],
#  ['Bhutan'],
#  ['Australia'],
#  ['Peru'],
#  ['Micronesia (Federated States of)'],
#  ['Chile'],
#  ['India'],
#  ['Tajikistan'],
#  ['Tajikistan', ' Afghanistan'],
#  ['Malaysia'],
#  ['Malaysia'],
#  ['Thailand'],
#  ['Chad'],
#  ['Gabon'],
#  ['Guatemala'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['Nepal'],
#  ['Mexico'],
#  ['Cameroon', ' Equatorial Guinea'],
#  ['Papua New Guinea'],
#  ['China'],
#  ['Viet Nam'],
#  ['Mexico'],
#  ['Canada'],
#  ['Chad'],
#  ['Brazil'],
#  ['Chad'],
#  ['Brazil'],
#  ['Malaysia'],
#  ['Peru'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Brazil'],
#  ['Australia'],
#  ['China'],
#  ['Costa Rica'],
#  ['India'],
#  ['Australia'],
#  ['Brazil'],
#  ['Australia'],
#  ['Afghanistan'],
#  ['Philippines'],
#  ['Nepal'],
#  ['Argentina'],
#  ['Ethiopia'],
#  ['India'],
#  ['Indonesia'],
#  ['China', ' India'],
#  ["Lao People's Democratic Republic"],
#  ['Pakistan'],
#  ['Brazil'],
#  ['Colombia'],
#  ['Nigeria'],
#  ['Brazil'],
#  ['Ethiopia'],
#  ['Indonesia'],
#  ['Libyan Arab Jamahiriya'],
#  ['Italy'],
#  ['Chile'],
#  ['Uganda'],
#  ['India'],
#  ['Nepal'],
#  ['French Guiana (France)'],
#  ['China', ' Mongolia, Russian Federation'],
#  ['Nigeria'],
#  ['Colombia'],
#  ['Russian Federation'],
#  ['India'],
#  ['Sudan'],
#  ['Norway', ' Sweden'],
#  ['India'],
#  ['Chad'],
#  ['India'],
#  ['Argentina'],
#  ['Indonesia'],
#  ['Thailand'],
#  ['China'],
#  ['Afghanistan'],
#  ['Viet Nam'],
#  ['Venezuela (Bolivarian Republic of)'],
#  ['India'],
#  ['Nepal'],
#  ['Canada', ' United States of America'],
#  ['Afghanistan'],
#  ['China'],
#  ['Colombia', ' Venezuela (Bolivarian Republic of)'],
#  ['China'],
#  ['Chad'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['Algeria'],
#  ['China'],
#  ...]

# %%
df.Speakers.value_counts?
# Out:
# Object `df.Speakers.value_counts` not found.

# %%
.value_counts
# Out:
#   File "<ipython-input-48-6c30a50e9308>", line 1
#     .value_counts
#     ^
# SyntaxError: invalid syntax

# %%
index = np.arange(len([df.Endangerment]))
#print(len(df.Endangerment))

# %%
#showing % at the y axis
plt.subplot?

# %%
## Creating a stacked bar chart
df.plot.bar?
#df[['Number of speakers', 'Degree of endangerment']].plot.bar(stacked=True)

# %%
df..plot.bar
# Out:
#   File "<ipython-input-52-5e0a27dbf6c4>", line 1
#     df..plot.bar
#        ^
# SyntaxError: invalid syntax

# %%
.plot.bar
# Out:
#   File "<ipython-input-53-7825585f5f9b>", line 1
#     .plot.bar
#     ^
# SyntaxError: invalid syntax

# %%
plt.hist(df['Number of speakers'], bins=200)
plt.xlim([0,1000000])
plt.xlabel("Number of speakers")

plt.ylabel("Number of languages")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-d8418a88b09e> in <module>()
#       1
#       2
# ----> 3 plt.hist(df['Number of speakers'], bins=200)
#       4 plt.xlim([0,1000000])
#       5 plt.xlabel("Number of speakers")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'

# %%
#plt.hist?
df.describe()
(df['Number of speakers'].max() - df['Number of speakers'].min())/200 #definition of bin
1000000/37500 #number of bins
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-7ee5428050d6> in <module>()
#       1 #plt.hist?
#       2 df.describe()
# ----> 3 (df['Number of speakers'].max() - df['Number of speakers'].min())/200 #definition of bin
#       4 1000000/37500 #number of bins
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'

# %%
#Stacked bar plot plotting different levels of endangerment in languages 
# count for speakers for each level
df.groupby(['Degree of endangerment']).count() #stat of all diff groups
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-964e31d31500> in <module>()
#       1 #Stacked bar plot plotting different levels of endangerment in languages
#       2 # count for speakers for each level
# ----> 3 df.groupby(['Degree of endangerment']).count() #stat of all diff groups
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# -> 1848     return klass(obj, by, **kwds)
#    1849
#    1850
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     514                                                     level=level,
#     515                                                     sort=sort,
# --> 516                                                     mutated=self.mutated)
#     517
#     518         self.obj = obj
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated, validate)
#    2932                 in_axis, name, level, gpr = False, None, gpr, None
#    2933             else:
# -> 2934                 raise KeyError(gpr)
#    2935         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2936             # Add key to exclusions
#
# KeyError: 'Degree of endangerment'

# %%
df['Description of the location']
df['Countries'].unique().shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Description of the location'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-7bf87101204d> in <module>()
# ----> 1 df['Description of the location']
#       2 df['Countries'].unique().shape
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Description of the location'

# %%
df['Number of alternative names'] = df['Alternate names'].apply(lambda x: len(x.split(';')))
df.head()

#now counted the number of alternative names and made a column with the number of alternative names
#next step is to do a scatterplot to see if there's a correlation between the number of names and how ancient a language is. 

######## as of 2nd mentor meeting.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-81b0f5b47627> in <module>()
# ----> 1 df['Number of alternative names'] = df['Alternate names'].apply(lambda x: len(x.split(';')))
#       2 df.head()
#       3
#       4 #now counted the number of alternative names and made a column with the number of alternative names
#       5 #next step is to do a scatterplot to see if there's a correlation between the number of names and how ancient a language is.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-58-81b0f5b47627> in <lambda>(x)
# ----> 1 df['Number of alternative names'] = df['Alternate names'].apply(lambda x: len(x.split(';')))
#       2 df.head()
#       3
#       4 #now counted the number of alternative names and made a column with the number of alternative names
#       5 #next step is to do a scatterplot to see if there's a correlation between the number of names and how ancient a language is.
#
# AttributeError: 'float' object has no attribute 'split'

# %%
Alt_name_numbers = len(df['Alternate names'].split(';'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-889ebddeee43> in <module>()
# ----> 1 Alt_name_numbers = len(df['Alternate names'].split(';'))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
print(df['Number of speakers'].isnull().sum())

df['Number of speakers'] = df['Number of speakers'].astype(int)

#df.Name_in_Country.value_counts().plot(kind = "bar")

df.describe()

import seaborn as sns

sns.distplot(df['Number of speakers'])
sns.distplot(df['Number of speakers'].dropna().astype(int))


#plots suggested by Lauren 

#plt.hist(df['Number_of_speakers'])
#
#df.Name_in_Country.value_counts().plot(kind = "bar")
#
#Chart 2 df.Countries.value_counts().plot(kind = "bar")
#
#Chart 3: df.Degree_of_Endagerment.value_counts().plot(kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-5387594f07d9> in <module>()
# ----> 1 print(df['Number of speakers'].isnull().sum())
#       2
#       3 df['Number of speakers'] = df['Number of speakers'].astype(int)
#       4
#       5 #df.Name_in_Country.value_counts().plot(kind = "bar")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'

# %%
#sns.distplot(df['Number of speakers'].dropna().astype(int))
plt.hist(df['Number of speakers'].dropna().astype(int))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-da6190bee94f> in <module>()
#       1
#       2 #sns.distplot(df['Number of speakers'].dropna().astype(int))
# ----> 3 plt.hist(df['Number of speakers'].dropna().astype(int))
#       4 plt.show()
#       5
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'

# %%
#creating country variables 
India = df[df.Countries == "India"]
usa = df[df.Countries == "United States of America"]
Mexico = df[df.Countries == "Mexico"]
Canada = df[df.Countries == "Canada"]

plt.hist(df['Number_of_speakers'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number_of_speakers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-824d31fd1882> in <module>()
#       5 Canada = df[df.Countries == "Canada"]
#       6
# ----> 7 plt.hist(df['Number_of_speakers'])
#       8 plt.show()
#       9
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number_of_speakers'

# %%
plt.figure(figsize=(15,8))
m = Basemap(projection = 'mill', llcrnrlat = 5, urcrnrlat = 40, llcrnrlon = 65, urcrnrlon = 98, resolution = 'h')
m.drawcoastlines()
m.drawcountries()

x, y = m(list(india_extinct["Longitude"].astype(float)), list(india_extinct["Latitude"].astype(float)))
m.plot(x, y, 'go', markersize = 10, alpha = 0.8)

plt.title('Extinct Languages - India')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-344948f94666> in <module>()
#       1 plt.figure(figsize=(15,8))
# ----> 2 m = Basemap(projection = 'mill', llcrnrlat = 5, urcrnrlat = 40, llcrnrlon = 65, urcrnrlon = 98, resolution = 'h')
#       3 m.drawcoastlines()
#       4 m.drawcountries()
#       5
#
# NameError: name 'Basemap' is not defined

# %%
#plt.scatter(df['Number of speakers']/1000, df['Degree of endangerment'],  color='red', label='all')
plt.scatter(India['Number of speakers']/1000, India['Degree of endangerment'],  color='blue', label='India')
plt.scatter(usa['Number of speakers']/1000, usa['Degree of endangerment'],  color='cyan', label='USA')
plt.scatter(Mexico['Number of speakers']/1000, Mexico['Degree of endangerment'],  color='red', label='Mexico')
plt.scatter(Canada['Number of speakers']/1000, Canada['Degree of endangerment'],  color='yellow', label='Canada')
plt.xlabel('Number of speakers in thousands')
plt.ylabel('Degrees of endangerment')
plt.title('Speakers for the degrees of endangerment')
plt.legend()

plt.show()

#extinct = df[df["Degree of endangerment"] == "Extinct"]
#india_extinct = df[(df.Countries == "India") & (df["Degree of endangerment"] == "Extinct")]
#usa_extinct = df[(df.Countries == "United States of America") & (df["Degree of endangerment"] == "Extinct")]
#
#plt.figure(figsize=(15,8))
#m = Basemap(projection = 'mill', llcrnrlat = 5, urcrnrlat = 37, llcrnrlon = 65, urcrnrlon = 98, resolution = 'h')
#m.drawcoastlines()
#m.drawcountries()
#
#x, y = m(list(india["Longitude"].astype(float)), list(india["Latitude"].astype(float)))
#m.plot(x, y, 'go', markersize = 10, alpha = 0.8)
#
#plt.title('Extinct and Endangered Languages - India')
#plt.show()
#
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-b6e51be5411e> in <module>()
#       1 #plt.scatter(df['Number of speakers']/1000, df['Degree of endangerment'],  color='red', label='all')
# ----> 2 plt.scatter(India['Number of speakers']/1000, India['Degree of endangerment'],  color='blue', label='India')
#       3 plt.scatter(usa['Number of speakers']/1000, usa['Degree of endangerment'],  color='cyan', label='USA')
#       4 plt.scatter(Mexico['Number of speakers']/1000, Mexico['Degree of endangerment'],  color='red', label='Mexico')
#       5 plt.scatter(Canada['Number of speakers']/1000, Canada['Degree of endangerment'],  color='yellow', label='Canada')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number of speakers'

# %%
plt.figure(figsize=(15,8))
m = Basemap(projection='mill', llcrnrlat = 20, urcrnrlat = 50, llcrnrlon = -130, urcrnrlon = -60, resolution = 'h')
m.drawcoastlines()
m.drawcountries()
m.drawstates()

x, y = m(list(usa["Longitude"].astype(float)), list(usa["Latitude"].astype(float)))
m.plot(x, y, 'go', markersize = 10, alpha = 0.8, color = "blue")

plt.title('Extinct and Endangered Languages in USA')
plt.show()

# %%
plt.figure(figsize=(15,8))
m = Basemap(projection='mill', llcrnrlat = 20, urcrnrlat = 50, llcrnrlon = -130, urcrnrlon = -60, resolution = 'h')
m.drawcoastlines()
m.drawcountries()
m.drawstates()

x, y = m(list(usa_extinct["Longitude"].astype(float)), list(usa_extinct["Latitude"].astype(float)))
m.plot(x, y, 'go', markersize = 10, alpha = 0.8, color = "blue")

plt.title('Extinct Languages in USA')
plt.show()

# %%
plt.figure(figsize=(15,8))
m = Basemap(projection = 'mill', llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180, resolution = 'h')
m.drawcoastlines()
m.drawcountries()

x, y = m(list(df["Longitude"].astype(float)), list(df["Latitude"].astype(float)))
m.plot(x, y, 'go', markersize = 10, alpha = 0.7, color = "red")

plt.title('Extinct and Endangered Languages Across the World')
plt.show()

# %%
plt.figure(figsize=(15,8))
m = Basemap(projection = 'mill', llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180, resolution = 'h')
m.drawcoastlines()
m.drawcountries()

x, y = m(list(extinct["Longitude"].astype(float)), list(extinct["Latitude"].astype(float)))
m.plot(x, y, 'go', markersize = 10, alpha = 0.8, color = "maroon")

plt.title('Extinct Languages Across the World')
plt.show()
